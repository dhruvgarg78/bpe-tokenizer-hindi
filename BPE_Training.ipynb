# %%
with open('hindilit.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print("the length of the data is: ", len(text))
print("the first 1000:", text[:1000])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with open('hindilit.txt', 'r', encoding='utf-8') as f:
#       2     text = f.read()
#       4 print("the length of the data is: ", len(text))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hindilit.txt'

# %%
normalization_dict = {
    # Variants of "मैं" (I)
    'मै': 'मैं',
    'मुझको': 'मुझे',
    'मुझसे': 'मुझे',
    'मैने': 'मैंने',

    # Variants of "यहाँ" (here) and "वहाँ" (there)
    'यहा': 'यहाँ',
    'वहा': 'वहाँ',

    # Variants of "क्यों" (why) and related forms
    'क्यु': 'क्यों',
    'क्युकी': 'क्योंकि',
    'क्यू': 'क्यों',

    # Variants of "तुम्हें" (you)
    'तुम्हे': 'तुम्हें',
    'तुमको': 'तुम्हें',

    # Variants of "हमें" (us)
    'हमको': 'हमें',
    'हमसे': 'हमें',

    # Variants of "करूं" (I do)
    'करु': 'करूं',
    'करूँ': 'करूं',  # Alternate Unicode representation

    # Variants of "गए" (went)
    'गये': 'गए',

    # Variants of "पढ़ाई" (study)
    'पढाई': 'पढ़ाई',
    'पढना': 'पढ़ना',

    # Casual/phonetic forms
    'कैसा': 'कैसे',  # Normalize gender-neutral "कैसे"
    'किसे': 'किसे',  # Sometimes used as "किसको"
    'जो': 'जो',  # Ensure no typo between "जो" and "झो"

    # Variants of common auxiliary verbs
    'हू': 'हूँ',
    'हैं': 'है',  # Simplify plural to singular for some cases
    'था': 'थे',  # Normalize tense differences
    'थी': 'थे',

    # Typo corrections
    'और': 'और',
    'से': 'से',
    'तो': 'तो',

}

# %%
import re

#Normalizing Orthographic Variations
for key, value in normalization_dict.items():
  # Replace variations using regex
  text = re.sub(r'\b' + re.escape(key) + r'\b', value, text)

#Compound words separated
# Replace hyphen-separated or underscore-separated compounds with space-separated words
text = re.sub(r'(\w+)[-_](\w+)', r'\1 \2', text)
# Replace other compound connectors (e.g., dots in specific cases)
text = re.sub(r'(\w+)\.(\w+)', r'\1 \2', text)

#Final cleaning of non-hindi characters
# Remove non-Devanagari characters and non-space characters
cleaned_text = re.sub(r'[^अ-ह\s]', '', text)

#Finally removing unecessary spaces and making it all one line
cleaned_text = re.sub(r'\s+', ' ', text).strip()  # Replace multiple spaces with a single space
print(cleaned_text[:1000])  # Output: "नमस्ते  है"
# Out:
# इसज समरत सध हइ गन नयक करबर बदन करउ अनगरह सइ बदध रस सभ गन सदन मक हइ बचल पग चढइ गरबर गहन जस कप स दयल दरवउ सकल कल मल दहन नल सररह सयम तरन अरन बरज नयन करउ स मम उर धम सद छरसगर सयन कद इद सम दह उम रमन करन अयन जह दन पर नह करउ कप मरदन मयन बदउ गर पद कज कप सध नररप हर महमह तम पज जस बचन रब कर नकर बदउ गर पद पदम परग सरच सबस सरस अनरग अमय मरमय चरन चर समन सकल भव रज परवर सकत सभ तन बमल बभत मजल मगल मद परसत जन मन मज मकर मल हरन कए तलक गन गन बस करन शरगर पद नख मन गन जत समरत दबय दरषट हय हत दलन मह तम स सपरकस बड भग उर आवइ जस उघरह बमल बलचन ह क मटह दष दख भव रजन क सझह रम चरत मन मनक गपत परगट जह ज जह खनक द जथ सअजन अज दग सधक सदध सजन कतक दखत सल बन भतल भर नधन एह मह रघपत नम उदर अत पवन परन शरत सर मगल भवन अमगल हर उम सहत जह जपत परर भनत बचतर सकब कत जऊ रम नम बन सह न सऊ बधबदन सब भत सवर सन न बसन बन बर नर सब गन रहत ककब कत बन रम नम जस अकत जन सदर कहह सनह बध तह मधकर सरस सत गनगरह जदप कबत रस एकउ नह रम परतप परकट एह मह सइ भरस मर मन आव कह न ससग बडपपन पव धमउ तजइ सहज करआई अगर परसग सगध बसई भनत भदस बसत भल बरन रम कथ जग मगल करन छ मगल करन कल मल

# %%
chars = sorted(list(set(cleaned_text)))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)
# Out:
#  अआइईउऊएऐओऔकखगघङचछजझटठडढणतथदधनपफबभमयरलवशषसह
# 43

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# %%
tokens = cleaned_text.encode("utf-8") # raw bytes
tokens = list(map(int, tokens)) # convert to a list of integers in range 0..255 for convenience

# %%
#Making pairs and getting a count
def get_stats(ids):
    counts = {}
    for pair in zip(ids, ids[1:]):
        counts[pair] = counts.get(pair, 0) + 1
    return counts
#Merging the given pair and giving it a new index
def merge(ids, pair, idx):
  newids = []
  i = 0
  while i < len(ids):
    if i < len(ids) - 1 and ids[i] == pair[0] and ids[i+1] == pair[1]:
      newids.append(idx)
      i += 2
    else:
      newids.append(ids[i])
      i += 1
  return newids

# %%
# ---
vocab_size = 4500 # the desired final vocabulary size
num_merges = vocab_size - 256
ids = list(tokens) # copy so we don't destroy the original list

merges = {} # (int, int) -> int
for i in range(num_merges):
  stats = get_stats(ids)
  pair = max(stats, key=stats.get)
  idx = 256 + i
  print(f"merging {pair} with freq {stats[pair]} into a new token {idx}")
  ids = merge(ids, pair, idx)
  merges[pair] = idx
# Out:
# merging (224, 164) with freq 96878 into a new token 256
# merging (32, 256) with freq 37331 into a new token 257
# merging (256, 176) with freq 9084 into a new token 258
# merging (256, 168) with freq 7540 into a new token 259
# merging (256, 185) with freq 6534 into a new token 260
# merging (257, 184) with freq 5745 into a new token 261
# merging (256, 164) with freq 4221 into a new token 262
# merging (259, 257) with freq 4102 into a new token 263
# merging (260, 257) with freq 4053 into a new token 264
# merging (258, 257) with freq 3854 into a new token 265
# merging (261, 256) with freq 3762 into a new token 266
# merging (172, 256) with freq 3001 into a new token 267
# merging (262, 257) with freq 2815 into a new token 268
# merging (258, 256) with freq 2782 into a new token 269
# merging (149, 256) with freq 2131 into a new token 270
# merging (256, 174) with freq 1785 into a new token 271
# merging (256, 184) with freq 1686 into a new token 272
# merging (256, 178) with freq 1509 into a new token 273
# merging (256, 181) with freq 1466 into a new token 274
# merging (257, 267) with freq 1417 into a new token 275
# merging (257, 156) with freq 1379 into a new token 276
# merging (256, 151) with freq 1377 into a new token 277
# merging (257, 170) with freq 1369 into a new token 278
# merging (257, 174) with freq 1318 into a new token 279
# merging (256, 175) with freq 1275 into a new token 280
# merging (256, 170) with freq 1207 into a new token 281
# merging (257, 168) with freq 1167 into a new token 282
# merging (257, 149) with freq 1166 into a new token 283
# merging (256, 149) with freq 1156 into a new token 284
# merging (256, 156) with freq 992 into a new token 285
# merging (256, 166) with freq 983 into a new token 286
# merging (257, 166) with freq 912 into a new token 287
# merging (257, 133) with freq 891 into a new token 288
# merging (257, 164) with freq 824 into a new token 289
# merging (257, 270) with freq 802 into a new token 290
# merging (257, 173) with freq 760 into a new token 291
# merging (257, 176) with freq 759 into a new token 292
# merging (259, 264) with freq 751 into a new token 293
# merging (257, 172) with freq 714 into a new token 294
# merging (256, 150) with freq 700 into a new token 295
# merging (256, 136) with freq 683 into a new token 296
# merging (257, 185) with freq 596 into a new token 297
# merging (256, 135) with freq 578 into a new token 298
# merging (256, 137) with freq 569 into a new token 299
# merging (266, 174) with freq 562 into a new token 300
# merging (257, 151) with freq 527 into a new token 301
# merging (256, 172) with freq 519 into a new token 302
# merging (266, 172) with freq 509 into a new token 303
# merging (256, 154) with freq 487 into a new token 304
# merging (278, 269) with freq 471 into a new token 305
# merging (170, 269) with freq 446 into a new token 306
# merging (270, 178) with freq 444 into a new token 307
# merging (256, 167) with freq 430 into a new token 308
# merging (256, 143) with freq 424 into a new token 309
# merging (263, 174) with freq 409 into a new token 310
# merging (257, 178) with freq 404 into a new token 311
# merging (258, 268) with freq 397 into a new token 312
# merging (259, 266) with freq 362 into a new token 313
# merging (257, 154) with freq 360 into a new token 314
# merging (261, 260) with freq 350 into a new token 315
# merging (265, 168) with freq 331 into a new token 316
# merging (260, 266) with freq 326 into a new token 317
# merging (258, 266) with freq 322 into a new token 318
# merging (256, 159) with freq 318 into a new token 319
# merging (258, 264) with freq 317 into a new token 320
# merging (263, 267) with freq 316 into a new token 321
# merging (256, 183) with freq 306 into a new token 322
# merging (265, 174) with freq 299 into a new token 323
# merging (263, 156) with freq 293 into a new token 324
# merging (265, 267) with freq 280 into a new token 325
# merging (263, 149) with freq 276 into a new token 326
# merging (264, 156) with freq 274 into a new token 327
# merging (264, 267) with freq 274 into a new token 328
# merging (265, 156) with freq 266 into a new token 329
# merging (259, 261) with freq 253 into a new token 330
# merging (264, 168) with freq 251 into a new token 331
# merging (263, 170) with freq 250 into a new token 332
# merging (264, 174) with freq 248 into a new token 333
# merging (257, 137) with freq 246 into a new token 334
# merging (257, 134) with freq 242 into a new token 335
# merging (258, 262) with freq 238 into a new token 336
# merging (265, 149) with freq 237 into a new token 337
# merging (268, 174) with freq 232 into a new token 338
# merging (256, 270) with freq 230 into a new token 339
# merging (263, 166) with freq 229 into a new token 340
# merging (275, 178) with freq 228 into a new token 341
# merging (256, 173) with freq 227 into a new token 342
# merging (292, 271) with freq 226 into a new token 343
# merging (265, 166) with freq 223 into a new token 344
# merging (263, 168) with freq 221 into a new token 345
# merging (256, 165) with freq 219 into a new token 346
# merging (265, 172) with freq 218 into a new token 347
# merging (259, 260) with freq 216 into a new token 348
# merging (269, 174) with freq 210 into a new token 349
# merging (257, 167) with freq 210 into a new token 350
# merging (265, 170) with freq 208 into a new token 351
# merging (256, 152) with freq 203 into a new token 352
# merging (265, 133) with freq 201 into a new token 353
# merging (263, 172) with freq 196 into a new token 354
# merging (263, 164) with freq 193 into a new token 355
# merging (287, 295) with freq 191 into a new token 356
# merging (268, 267) with freq 189 into a new token 357
# merging (263, 176) with freq 186 into a new token 358
# merging (262, 266) with freq 186 into a new token 359
# merging (269, 183) with freq 186 into a new token 360
# merging (263, 133) with freq 185 into a new token 361
# merging (256, 267) with freq 182 into a new token 362
# merging (258, 261) with freq 182 into a new token 363
# merging (264, 166) with freq 178 into a new token 364
# merging (263, 151) with freq 177 into a new token 365
# merging (263, 173) with freq 177 into a new token 366
# merging (268, 168) with freq 175 into a new token 367
# merging (275, 184) with freq 175 into a new token 368
# merging (264, 164) with freq 171 into a new token 369
# merging (258, 260) with freq 170 into a new token 370
# merging (283, 260) with freq 170 into a new token 371
# merging (268, 133) with freq 168 into a new token 372
# merging (259, 284) with freq 165 into a new token 373
# merging (264, 149) with freq 162 into a new token 374
# merging (256, 155) with freq 161 into a new token 375
# merging (269, 184) with freq 160 into a new token 376
# merging (275, 154) with freq 155 into a new token 377
# merging (268, 170) with freq 155 into a new token 378
# merging (265, 173) with freq 155 into a new token 379
# merging (275, 167) with freq 155 into a new token 380
# merging (276, 277) with freq 155 into a new token 381
# merging (265, 164) with freq 155 into a new token 382
# merging (265, 270) with freq 154 into a new token 383
# merging (265, 185) with freq 152 into a new token 384
# merging (269, 156) with freq 149 into a new token 385
# merging (264, 170) with freq 148 into a new token 386
# merging (266, 181) with freq 146 into a new token 387
# merging (256, 161) with freq 146 into a new token 388
# merging (266, 150) with freq 146 into a new token 389
# merging (266, 173) with freq 144 into a new token 390
# merging (257, 143) with freq 141 into a new token 391
# merging (268, 156) with freq 140 into a new token 392
# merging (260, 261) with freq 139 into a new token 393
# merging (268, 149) with freq 138 into a new token 394
# merging (259, 271) with freq 138 into a new token 395
# merging (264, 173) with freq 137 into a new token 396
# merging (263, 270) with freq 136 into a new token 397
# merging (256, 138) with freq 136 into a new token 398
# merging (265, 151) with freq 134 into a new token 399
# merging (256, 160) with freq 134 into a new token 400
# merging (290, 178) with freq 131 into a new token 401
# merging (264, 176) with freq 131 into a new token 402
# merging (263, 185) with freq 127 into a new token 403
# merging (282, 285) with freq 127 into a new token 404
# merging (275, 166) with freq 126 into a new token 405
# merging (269, 166) with freq 125 into a new token 406
# merging (268, 176) with freq 125 into a new token 407
# merging (264, 133) with freq 125 into a new token 408
# merging (268, 173) with freq 124 into a new token 409
# merging (264, 270) with freq 123 into a new token 410
# merging (286, 280) with freq 123 into a new token 411
# merging (265, 154) with freq 122 into a new token 412
# merging (265, 176) with freq 122 into a new token 413
# merging (257, 155) with freq 121 into a new token 414
# merging (262, 261) with freq 121 into a new token 415
# merging (269, 151) with freq 120 into a new token 416
# merging (259, 280) with freq 120 into a new token 417
# merging (288, 272) with freq 119 into a new token 418
# merging (266, 307) with freq 117 into a new token 419
# merging (269, 170) with freq 117 into a new token 420
# merging (277, 273) with freq 116 into a new token 421
# merging (264, 172) with freq 116 into a new token 422
# merging (266, 166) with freq 115 into a new token 423
# merging (294, 260) with freq 115 into a new token 424
# merging (268, 185) with freq 114 into a new token 425
# merging (289, 271) with freq 114 into a new token 426
# merging (268, 166) with freq 113 into a new token 427
# merging (263, 306) with freq 111 into a new token 428
# merging (305, 173) with freq 110 into a new token 429
# merging (178, 277) with freq 105 into a new token 430
# merging (259, 272) with freq 103 into a new token 431
# merging (305, 174) with freq 103 into a new token 432
# merging (291, 277) with freq 100 into a new token 433
# merging (266, 175) with freq 99 into a new token 434
# merging (274, 272) with freq 99 into a new token 435
# merging (263, 154) with freq 97 into a new token 436
# merging (259, 286) with freq 97 into a new token 437
# merging (293, 149) with freq 97 into a new token 438
# merging (290, 170) with freq 95 into a new token 439
# merging (279, 260) with freq 94 into a new token 440
# merging (268, 164) with freq 92 into a new token 441
# merging (290, 174) with freq 92 into a new token 442
# merging (265, 306) with freq 91 into a new token 443
# merging (256, 133) with freq 91 into a new token 444
# merging (256, 162) with freq 89 into a new token 445
# merging (273, 284) with freq 89 into a new token 446
# merging (266, 184) with freq 89 into a new token 447
# merging (266, 149) with freq 89 into a new token 448
# merging (287, 272) with freq 89 into a new token 449
# merging (280, 299) with freq 89 into a new token 450
# merging (258, 259) with freq 88 into a new token 451
# merging (265, 167) with freq 87 into a new token 452
# merging (264, 151) with freq 87 into a new token 453
# merging (264, 306) with freq 87 into a new token 454
# merging (261, 259) with freq 85 into a new token 455
# merging (279, 286) with freq 83 into a new token 456
# merging (268, 151) with freq 83 into a new token 457
# merging (283, 293) with freq 83 into a new token 458
# merging (268, 306) with freq 82 into a new token 459
# merging (279, 273) with freq 81 into a new token 460
# merging (276, 272) with freq 81 into a new token 461
# merging (291, 274) with freq 81 into a new token 462
# merging (268, 172) with freq 81 into a new token 463
# merging (265, 134) with freq 80 into a new token 464
# merging (267, 167) with freq 80 into a new token 465
# merging (311, 277) with freq 80 into a new token 466
# merging (269, 165) with freq 80 into a new token 467
# merging (288, 259) with freq 79 into a new token 468
# merging (264, 154) with freq 79 into a new token 469
# merging (263, 167) with freq 79 into a new token 470
# merging (282, 281) with freq 79 into a new token 471
# merging (314, 273) with freq 78 into a new token 472
# merging (282, 271) with freq 77 into a new token 473
# merging (268, 270) with freq 76 into a new token 474
# merging (292, 352) with freq 76 into a new token 475
# merging (261, 262) with freq 75 into a new token 476
# merging (256, 307) with freq 75 into a new token 477
# merging (265, 178) with freq 75 into a new token 478
# merging (263, 134) with freq 73 into a new token 479
# merging (264, 185) with freq 73 into a new token 480
# merging (289, 302) with freq 73 into a new token 481
# merging (171, 273) with freq 71 into a new token 482
# merging (276, 298) with freq 71 into a new token 483
# merging (268, 154) with freq 71 into a new token 484
# merging (278, 274) with freq 70 into a new token 485
# merging (263, 178) with freq 70 into a new token 486
# merging (266, 156) with freq 69 into a new token 487
# merging (290, 184) with freq 69 into a new token 488
# merging (297, 360) with freq 69 into a new token 489
# merging (266, 167) with freq 68 into a new token 490
# merging (391, 284) with freq 68 into a new token 491
# merging (178, 284) with freq 68 into a new token 492
# merging (256, 157) with freq 67 into a new token 493
# merging (288, 274) with freq 66 into a new token 494
# merging (279, 277) with freq 66 into a new token 495
# merging (328, 167) with freq 66 into a new token 496
# merging (283, 269) with freq 65 into a new token 497
# merging (266, 151) with freq 65 into a new token 498
# merging (341, 284) with freq 65 into a new token 499
# merging (297, 271) with freq 64 into a new token 500
# merging (258, 303) with freq 63 into a new token 501
# merging (259, 317) with freq 63 into a new token 502
# merging (370, 271) with freq 63 into a new token 503
# merging (257, 150) with freq 63 into a new token 504
# merging (293, 174) with freq 63 into a new token 505
# merging (296, 276) with freq 62 into a new token 506
# merging (290, 155) with freq 62 into a new token 507
# merging (263, 137) with freq 61 into a new token 508
# merging (298, 282) with freq 61 into a new token 509
# merging (278, 286) with freq 60 into a new token 510
# merging (267, 184) with freq 60 into a new token 511
# merging (292, 285) with freq 60 into a new token 512
# merging (260, 272) with freq 60 into a new token 513
# merging (288, 277) with freq 59 into a new token 514
# merging (294, 259) with freq 59 into a new token 515
# merging (257, 182) with freq 59 into a new token 516
# merging (426, 260) with freq 59 into a new token 517
# merging (291, 281) with freq 59 into a new token 518
# merging (300, 285) with freq 58 into a new token 519
# merging (275, 161) with freq 57 into a new token 520
# merging (283, 320) with freq 57 into a new token 521
# merging (275, 175) with freq 57 into a new token 522
# merging (266, 154) with freq 57 into a new token 523
# merging (264, 134) with freq 57 into a new token 524
# merging (278, 258) with freq 56 into a new token 525
# merging (276, 259) with freq 56 into a new token 526
# merging (279, 310) with freq 56 into a new token 527
# merging (269, 154) with freq 55 into a new token 528
# merging (262, 284) with freq 55 into a new token 529
# merging (297, 411) with freq 55 into a new token 530
# merging (269, 167) with freq 55 into a new token 531
# merging (269, 172) with freq 54 into a new token 532
# merging (305, 184) with freq 54 into a new token 533
# merging (300, 493) with freq 54 into a new token 534
# merging (275, 183) with freq 54 into a new token 535
# merging (287, 274) with freq 54 into a new token 536
# merging (259, 308) with freq 54 into a new token 537
# merging (257, 135) with freq 53 into a new token 538
# merging (151, 319) with freq 53 into a new token 539
# merging (278, 336) with freq 53 into a new token 540
# merging (315, 285) with freq 53 into a new token 541
# merging (358, 271) with freq 52 into a new token 542
# merging (304, 375) with freq 52 into a new token 543
# merging (303, 283) with freq 52 into a new token 544
# merging (269, 173) with freq 51 into a new token 545
# merging (269, 137) with freq 50 into a new token 546
# merging (265, 137) with freq 50 into a new token 547
# merging (311, 295) with freq 50 into a new token 548
# merging (288, 281) with freq 50 into a new token 549
# merging (280, 276) with freq 50 into a new token 550
# merging (297, 298) with freq 49 into a new token 551
# merging (334, 281) with freq 49 into a new token 552
# merging (260, 299) with freq 49 into a new token 553
# merging (261, 258) with freq 48 into a new token 554
# merging (321, 184) with freq 48 into a new token 555
# merging (402, 271) with freq 48 into a new token 556
# merging (273, 272) with freq 48 into a new token 557
# merging (292, 281) with freq 48 into a new token 558
# merging (275, 170) with freq 48 into a new token 559
# merging (321, 178) with freq 48 into a new token 560
# merging (266, 135) with freq 47 into a new token 561
# merging (293, 168) with freq 47 into a new token 562
# merging (282, 272) with freq 47 into a new token 563
# merging (288, 302) with freq 47 into a new token 564
# merging (269, 181) with freq 46 into a new token 565
# merging (275, 150) with freq 46 into a new token 566
# merging (279, 259) with freq 46 into a new token 567
# merging (293, 170) with freq 46 into a new token 568
# merging (269, 149) with freq 45 into a new token 569
# merging (292, 304) with freq 45 into a new token 570
# merging (290, 159) with freq 45 into a new token 571
# merging (263, 155) with freq 44 into a new token 572
# merging (301, 274) with freq 44 into a new token 573
# merging (294, 503) with freq 44 into a new token 574
# merging (143, 284) with freq 44 into a new token 575
# merging (271, 260) with freq 44 into a new token 576
# merging (296, 287) with freq 44 into a new token 577
# merging (182, 349) with freq 44 into a new token 578
# merging (266, 178) with freq 44 into a new token 579
# merging (313, 166) with freq 43 into a new token 580
# merging (174, 273) with freq 43 into a new token 581
# merging (290, 165) with freq 43 into a new token 582
# merging (266, 170) with freq 43 into a new token 583
# merging (269, 175) with freq 43 into a new token 584
# merging (291, 309) with freq 43 into a new token 585
# merging (279, 421) with freq 42 into a new token 586
# merging (283, 258) with freq 42 into a new token 587
# merging (364, 295) with freq 42 into a new token 588
# merging (315, 296) with freq 42 into a new token 589
# merging (270, 154) with freq 42 into a new token 590
# merging (291, 273) with freq 42 into a new token 591
# merging (269, 136) with freq 42 into a new token 592
# merging (291, 285) with freq 42 into a new token 593
# merging (293, 166) with freq 42 into a new token 594
# merging (267, 149) with freq 41 into a new token 595
# merging (340, 295) with freq 41 into a new token 596
# merging (268, 178) with freq 41 into a new token 597
# merging (293, 156) with freq 41 into a new token 598
# merging (280, 272) with freq 41 into a new token 599
# merging (344, 295) with freq 41 into a new token 600
# merging (261, 376) with freq 40 into a new token 601
# merging (259, 303) with freq 40 into a new token 602
# merging (286, 281) with freq 40 into a new token 603
# merging (294, 258) with freq 40 into a new token 604
# merging (276, 273) with freq 40 into a new token 605
# merging (371, 299) with freq 40 into a new token 606
# merging (289, 281) with freq 40 into a new token 607
# merging (362, 184) with freq 40 into a new token 608
# merging (258, 300) with freq 39 into a new token 609
# merging (278, 312) with freq 39 into a new token 610
# merging (293, 133) with freq 39 into a new token 611
# merging (325, 184) with freq 39 into a new token 612
# merging (262, 274) with freq 39 into a new token 613
# merging (280, 398) with freq 39 into a new token 614
# merging (362, 178) with freq 39 into a new token 615
# merging (271, 280) with freq 38 into a new token 616
# merging (257, 152) with freq 38 into a new token 617
# merging (293, 267) with freq 38 into a new token 618
# merging (260, 303) with freq 38 into a new token 619
# merging (299, 291) with freq 38 into a new token 620
# merging (268, 137) with freq 38 into a new token 621
# merging (275, 156) with freq 38 into a new token 622
# merging (318, 166) with freq 38 into a new token 623
# merging (407, 271) with freq 37 into a new token 624
# merging (259, 300) with freq 37 into a new token 625
# merging (276, 373) with freq 37 into a new token 626
# merging (264, 307) with freq 37 into a new token 627
# merging (264, 178) with freq 37 into a new token 628
# merging (288, 308) with freq 37 into a new token 629
# merging (325, 178) with freq 37 into a new token 630
# merging (293, 164) with freq 37 into a new token 631
# merging (292, 272) with freq 36 into a new token 632
# merging (264, 137) with freq 36 into a new token 633
# merging (297, 280) with freq 36 into a new token 634
# merging (286, 272) with freq 36 into a new token 635
# merging (324, 277) with freq 36 into a new token 636
# merging (276, 271) with freq 36 into a new token 637
# merging (271, 273) with freq 36 into a new token 638
# merging (262, 303) with freq 35 into a new token 639
# merging (277, 271) with freq 35 into a new token 640
# merging (260, 300) with freq 35 into a new token 641
# merging (292, 295) with freq 35 into a new token 642
# merging (348, 300) with freq 35 into a new token 643
# merging (315, 309) with freq 35 into a new token 644
# merging (318, 150) with freq 35 into a new token 645
# merging (265, 155) with freq 35 into a new token 646
# merging (282, 280) with freq 34 into a new token 647
# merging (314, 258) with freq 34 into a new token 648
# merging (289, 285) with freq 34 into a new token 649
# merging (279, 295) with freq 34 into a new token 650
# merging (256, 134) with freq 34 into a new token 651
# merging (263, 430) with freq 34 into a new token 652
# merging (321, 166) with freq 33 into a new token 653
# merging (313, 307) with freq 33 into a new token 654
# merging (372, 259) with freq 33 into a new token 655
# merging (259, 285) with freq 33 into a new token 656
# merging (328, 184) with freq 33 into a new token 657
# merging (283, 331) with freq 32 into a new token 658
# merging (366, 274) with freq 32 into a new token 659
# merging (315, 274) with freq 32 into a new token 660
# merging (311, 284) with freq 32 into a new token 661
# merging (267, 166) with freq 32 into a new token 662
# merging (321, 167) with freq 32 into a new token 663
# merging (362, 167) with freq 32 into a new token 664
# merging (291, 450) with freq 32 into a new token 665
# merging (257, 175) with freq 32 into a new token 666
# merging (268, 134) with freq 32 into a new token 667
# merging (305, 175) with freq 31 into a new token 668
# merging (305, 539) with freq 31 into a new token 669
# merging (262, 280) with freq 31 into a new token 670
# merging (301, 280) with freq 31 into a new token 671
# merging (313, 150) with freq 31 into a new token 672
# merging (368, 322) with freq 31 into a new token 673
# merging (293, 176) with freq 31 into a new token 674
# merging (325, 166) with freq 30 into a new token 675
# merging (262, 300) with freq 30 into a new token 676
# merging (270, 184) with freq 30 into a new token 677
# merging (540, 281) with freq 30 into a new token 678
# merging (312, 149) with freq 30 into a new token 679
# merging (440, 272) with freq 30 into a new token 680
# merging (257, 482) with freq 30 into a new token 681
# merging (269, 135) with freq 30 into a new token 682
# merging (276, 274) with freq 30 into a new token 683
# merging (276, 395) with freq 30 into a new token 684
# merging (326, 320) with freq 30 into a new token 685
# merging (339, 159) with freq 30 into a new token 686
# merging (428, 174) with freq 30 into a new token 687
# merging (312, 174) with freq 29 into a new token 688
# merging (290, 172) with freq 29 into a new token 689
# merging (328, 166) with freq 29 into a new token 690
# merging (313, 173) with freq 29 into a new token 691
# merging (315, 272) with freq 29 into a new token 692
# merging (278, 332) with freq 29 into a new token 693
# merging (276, 302) with freq 29 into a new token 694
# merging (313, 181) with freq 29 into a new token 695
# merging (257, 171) with freq 29 into a new token 696
# merging (413, 271) with freq 29 into a new token 697
# merging (321, 154) with freq 29 into a new token 698
# merging (408, 272) with freq 29 into a new token 699
# merging (334, 400) with freq 29 into a new token 700
# merging (336, 261) with freq 28 into a new token 701
# merging (325, 154) with freq 28 into a new token 702
# merging (290, 137) with freq 28 into a new token 703
# merging (383, 170) with freq 28 into a new token 704
# merging (269, 150) with freq 28 into a new token 705
# merging (257, 165) with freq 28 into a new token 706
# merging (265, 307) with freq 28 into a new token 707
# merging (312, 156) with freq 28 into a new token 708
# merging (318, 181) with freq 28 into a new token 709
# merging (276, 296) with freq 28 into a new token 710
# merging (318, 307) with freq 28 into a new token 711
# merging (275, 151) with freq 28 into a new token 712
# merging (317, 173) with freq 28 into a new token 713
# merging (275, 174) with freq 28 into a new token 714
# merging (317, 181) with freq 28 into a new token 715
# merging (285, 279) with freq 27 into a new token 716
# merging (306, 174) with freq 27 into a new token 717
# merging (283, 329) with freq 27 into a new token 718
# merging (260, 304) with freq 27 into a new token 719
# merging (442, 273) with freq 27 into a new token 720
# merging (278, 259) with freq 27 into a new token 721
# merging (294, 347) with freq 27 into a new token 722
# merging (374, 260) with freq 27 into a new token 723
# merging (334, 271) with freq 27 into a new token 724
# merging (339, 174) with freq 27 into a new token 725
# merging (333, 286) with freq 27 into a new token 726
# merging (256, 578) with freq 27 into a new token 727
# merging (280, 284) with freq 26 into a new token 728
# merging (337, 260) with freq 26 into a new token 729
# merging (350, 349) with freq 26 into a new token 730
# merging (353, 272) with freq 26 into a new token 731
# merging (312, 133) with freq 26 into a new token 732
# merging (318, 173) with freq 26 into a new token 733
# merging (264, 167) with freq 26 into a new token 734
# merging (439, 273) with freq 26 into a new token 735
# merging (488, 273) with freq 26 into a new token 736
# merging (259, 296) with freq 26 into a new token 737
# merging (436, 273) with freq 26 into a new token 738
# merging (275, 160) with freq 26 into a new token 739
# merging (318, 175) with freq 25 into a new token 740
# merging (260, 271) with freq 25 into a new token 741
# merging (278, 285) with freq 25 into a new token 742
# merging (313, 156) with freq 25 into a new token 743
# merging (325, 167) with freq 25 into a new token 744
# merging (269, 178) with freq 25 into a new token 745
# merging (297, 296) with freq 25 into a new token 746
# merging (339, 156) with freq 25 into a new token 747
# merging (274, 299) with freq 25 into a new token 748
# merging (317, 166) with freq 25 into a new token 749
# merging (286, 274) with freq 25 into a new token 750
# merging (289, 272) with freq 25 into a new token 751
# merging (335, 274) with freq 25 into a new token 752
# merging (428, 173) with freq 25 into a new token 753
# merging (312, 267) with freq 25 into a new token 754
# merging (261, 316) with freq 25 into a new token 755
# merging (260, 281) with freq 25 into a new token 756
# merging (351, 286) with freq 24 into a new token 757
# merging (301, 365) with freq 24 into a new token 758
# merging (276, 327) with freq 24 into a new token 759
# merging (352, 281) with freq 24 into a new token 760
# merging (357, 154) with freq 24 into a new token 761
# merging (362, 166) with freq 24 into a new token 762
# merging (310, 286) with freq 24 into a new token 763
# merging (314, 262) with freq 24 into a new token 764
# merging (288, 342) with freq 24 into a new token 765
# merging (272, 284) with freq 24 into a new token 766
# merging (390, 277) with freq 24 into a new token 767
# merging (313, 175) with freq 24 into a new token 768
# merging (427, 295) with freq 24 into a new token 769
# merging (282, 346) with freq 24 into a new token 770
# merging (289, 274) with freq 24 into a new token 771
# merging (263, 307) with freq 23 into a new token 772
# merging (259, 346) with freq 23 into a new token 773
# merging (392, 277) with freq 23 into a new token 774
# merging (273, 282) with freq 23 into a new token 775
# merging (278, 296) with freq 23 into a new token 776
# merging (317, 150) with freq 23 into a new token 777
# merging (290, 160) with freq 23 into a new token 778
# merging (297, 272) with freq 23 into a new token 779
# merging (443, 173) with freq 23 into a new token 780
# merging (475, 302) with freq 23 into a new token 781
# merging (292, 260) with freq 23 into a new token 782
# merging (494, 308) with freq 23 into a new token 783
# merging (359, 150) with freq 23 into a new token 784
# merging (335, 281) with freq 23 into a new token 785
# merging (403, 360) with freq 23 into a new token 786
# merging (361, 272) with freq 23 into a new token 787
# merging (278, 375) with freq 23 into a new token 788
# merging (320, 174) with freq 23 into a new token 789
# merging (443, 174) with freq 23 into a new token 790
# merging (335, 309) with freq 23 into a new token 791
# merging (275, 173) with freq 22 into a new token 792
# merging (404, 404) with freq 22 into a new token 793
# merging (268, 167) with freq 22 into a new token 794
# merging (454, 184) with freq 22 into a new token 795
# merging (337, 320) with freq 22 into a new token 796
# merging (316, 316) with freq 22 into a new token 797
# merging (318, 184) with freq 22 into a new token 798
# merging (259, 281) with freq 22 into a new token 799
# merging (316, 271) with freq 22 into a new token 800
# merging (358, 285) with freq 22 into a new token 801
# merging (469, 273) with freq 22 into a new token 802
# merging (414, 302) with freq 22 into a new token 803
# merging (283, 327) with freq 22 into a new token 804
# merging (290, 156) with freq 21 into a new token 805
# merging (312, 170) with freq 21 into a new token 806
# merging (288, 285) with freq 21 into a new token 807
# merging (165, 271) with freq 21 into a new token 808
# merging (282, 406) with freq 21 into a new token 809
# merging (312, 151) with freq 21 into a new token 810
# merging (266, 136) with freq 21 into a new token 811
# merging (290, 136) with freq 21 into a new token 812
# merging (288, 271) with freq 21 into a new token 813
# merging (284, 276) with freq 21 into a new token 814
# merging (428, 184) with freq 21 into a new token 815
# merging (264, 430) with freq 21 into a new token 816
# merging (339, 136) with freq 21 into a new token 817
# merging (275, 465) with freq 21 into a new token 818
# merging (170, 273) with freq 21 into a new token 819
# merging (348, 261) with freq 21 into a new token 820
# merging (303, 291) with freq 21 into a new token 821
# merging (347, 260) with freq 21 into a new token 822
# merging (357, 166) with freq 21 into a new token 823
# merging (269, 133) with freq 21 into a new token 824
# merging (345, 271) with freq 21 into a new token 825
# merging (257, 161) with freq 21 into a new token 826
# merging (282, 277) with freq 21 into a new token 827
# merging (287, 299) with freq 21 into a new token 828
# merging (311, 304) with freq 21 into a new token 829
# merging (273, 291) with freq 20 into a new token 830
# merging (339, 165) with freq 20 into a new token 831
# merging (655, 416) with freq 20 into a new token 832
# merging (284, 261) with freq 20 into a new token 833
# merging (339, 184) with freq 20 into a new token 834
# merging (354, 260) with freq 20 into a new token 835
# merging (321, 156) with freq 20 into a new token 836
# merging (313, 151) with freq 20 into a new token 837
# merging (368, 274) with freq 20 into a new token 838
# merging (357, 184) with freq 20 into a new token 839
# merging (357, 167) with freq 20 into a new token 840
# merging (265, 430) with freq 20 into a new token 841
# merging (274, 285) with freq 20 into a new token 842
# merging (296, 289) with freq 20 into a new token 843
# merging (281, 584) with freq 20 into a new token 844
# merging (459, 174) with freq 20 into a new token 845
# merging (279, 262) with freq 20 into a new token 846
# merging (265, 152) with freq 20 into a new token 847
# merging (275, 172) with freq 20 into a new token 848
# merging (620, 296) with freq 20 into a new token 849
# merging (309, 287) with freq 20 into a new token 850
# merging (345, 281) with freq 20 into a new token 851
# merging (317, 175) with freq 19 into a new token 852
# merging (312, 173) with freq 19 into a new token 853
# merging (313, 167) with freq 19 into a new token 854
# merging (258, 326) with freq 19 into a new token 855
# merging (359, 307) with freq 19 into a new token 856
# merging (262, 272) with freq 19 into a new token 857
# merging (504, 273) with freq 19 into a new token 858
# merging (372, 272) with freq 19 into a new token 859
# merging (396, 274) with freq 19 into a new token 860
# merging (259, 274) with freq 19 into a new token 861
# merging (268, 155) with freq 19 into a new token 862
# merging (317, 307) with freq 19 into a new token 863
# merging (261, 406) with freq 19 into a new token 864
# merging (433, 274) with freq 19 into a new token 865
# merging (293, 185) with freq 19 into a new token 866
# merging (289, 557) with freq 19 into a new token 867
# merging (276, 281) with freq 19 into a new token 868
# merging (312, 168) with freq 19 into a new token 869
# merging (279, 348) with freq 19 into a new token 870
# merging (364, 272) with freq 19 into a new token 871
# merging (305, 172) with freq 19 into a new token 872
# merging (311, 285) with freq 19 into a new token 873
# merging (335, 599) with freq 19 into a new token 874
# merging (468, 416) with freq 18 into a new token 875
# merging (359, 173) with freq 18 into a new token 876
# merging (310, 310) with freq 18 into a new token 877
# merging (279, 319) with freq 18 into a new token 878
# merging (320, 156) with freq 18 into a new token 879
# merging (287, 322) with freq 18 into a new token 880
# merging (345, 285) with freq 18 into a new token 881
# merging (508, 281) with freq 18 into a new token 882
# merging (326, 260) with freq 18 into a new token 883
# merging (266, 590) with freq 18 into a new token 884
# merging (384, 360) with freq 18 into a new token 885
# merging (282, 284) with freq 18 into a new token 886
# merging (397, 170) with freq 18 into a new token 887
# merging (328, 178) with freq 18 into a new token 888
# merging (312, 172) with freq 18 into a new token 889
# merging (459, 173) with freq 18 into a new token 890
# merging (278, 451) with freq 18 into a new token 891
# merging (293, 172) with freq 18 into a new token 892
# merging (357, 178) with freq 18 into a new token 893
# merging (279, 308) with freq 18 into a new token 894
# merging (151, 280) with freq 18 into a new token 895
# merging (468, 281) with freq 18 into a new token 896
# merging (258, 315) with freq 18 into a new token 897
# merging (391, 496) with freq 18 into a new token 898
# merging (279, 431) with freq 18 into a new token 899
# merging (259, 322) with freq 18 into a new token 900
# merging (454, 173) with freq 18 into a new token 901
# merging (383, 184) with freq 18 into a new token 902
# merging (348, 315) with freq 18 into a new token 903
# merging (278, 262) with freq 18 into a new token 904
# merging (259, 435) with freq 18 into a new token 905
# merging (449, 467) with freq 18 into a new token 906
# merging (323, 273) with freq 17 into a new token 907
# merging (312, 166) with freq 17 into a new token 908
# merging (269, 138) with freq 17 into a new token 909
# merging (285, 285) with freq 17 into a new token 910
# merging (296, 261) with freq 17 into a new token 911
# merging (328, 154) with freq 17 into a new token 912
# merging (279, 280) with freq 17 into a new token 913
# merging (381, 276) with freq 17 into a new token 914
# merging (475, 281) with freq 17 into a new token 915
# merging (288, 373) with freq 17 into a new token 916
# merging (629, 284) with freq 17 into a new token 917
# merging (327, 272) with freq 17 into a new token 918
# merging (294, 417) with freq 17 into a new token 919
# merging (294, 451) with freq 17 into a new token 920
# merging (279, 272) with freq 17 into a new token 921
# merging (379, 277) with freq 17 into a new token 922
# merging (368, 273) with freq 17 into a new token 923
# merging (301, 309) with freq 17 into a new token 924
# merging (334, 375) with freq 17 into a new token 925
# merging (286, 342) with freq 17 into a new token 926
# merging (353, 302) with freq 17 into a new token 927
# merging (412, 273) with freq 17 into a new token 928
# merging (318, 154) with freq 17 into a new token 929
# merging (293, 173) with freq 17 into a new token 930
# merging (264, 155) with freq 17 into a new token 931
# merging (331, 281) with freq 17 into a new token 932
# merging (314, 445) with freq 16 into a new token 933
# merging (279, 271) with freq 16 into a new token 934
# merging (285, 273) with freq 16 into a new token 935
# merging (317, 156) with freq 16 into a new token 936
# merging (279, 304) with freq 16 into a new token 937
# merging (258, 310) with freq 16 into a new token 938
# merging (294, 385) with freq 16 into a new token 939
# merging (304, 273) with freq 16 into a new token 940
# merging (273, 339) with freq 16 into a new token 941
# merging (287, 298) with freq 16 into a new token 942
# merging (290, 149) with freq 16 into a new token 943
# merging (397, 184) with freq 16 into a new token 944
# merging (287, 273) with freq 16 into a new token 945
# merging (266, 183) with freq 16 into a new token 946
# merging (282, 260) with freq 16 into a new token 947
# merging (325, 175) with freq 16 into a new token 948
# merging (333, 273) with freq 16 into a new token 949
# merging (329, 277) with freq 16 into a new token 950
# merging (269, 267) with freq 16 into a new token 951
# merging (275, 162) with freq 16 into a new token 952
# merging (299, 282) with freq 16 into a new token 953
# merging (293, 306) with freq 16 into a new token 954
# merging (265, 143) with freq 16 into a new token 955
# merging (296, 283) with freq 16 into a new token 956
# merging (288, 260) with freq 16 into a new token 957
# merging (384, 298) with freq 16 into a new token 958
# merging (397, 174) with freq 16 into a new token 959
# merging (272, 304) with freq 16 into a new token 960
# merging (301, 285) with freq 16 into a new token 961
# merging (355, 302) with freq 16 into a new token 962
# merging (320, 172) with freq 16 into a new token 963
# merging (409, 274) with freq 16 into a new token 964
# merging (320, 168) with freq 16 into a new token 965
# merging (332, 446) with freq 16 into a new token 966
# merging (322, 319) with freq 16 into a new token 967
# merging (283, 529) with freq 16 into a new token 968
# merging (335, 272) with freq 16 into a new token 969
# merging (276, 369) with freq 16 into a new token 970
# merging (401, 272) with freq 16 into a new token 971
# merging (377, 330) with freq 16 into a new token 972
# merging (400, 309) with freq 16 into a new token 973
# merging (277, 280) with freq 16 into a new token 974
# merging (325, 156) with freq 16 into a new token 975
# merging (290, 133) with freq 16 into a new token 976
# merging (271, 261) with freq 15 into a new token 977
# merging (350, 271) with freq 15 into a new token 978
# merging (276, 280) with freq 15 into a new token 979
# merging (278, 280) with freq 15 into a new token 980
# merging (263, 150) with freq 15 into a new token 981
# merging (270, 170) with freq 15 into a new token 982
# merging (304, 385) with freq 15 into a new token 983
# merging (276, 388) with freq 15 into a new token 984
# merging (313, 178) with freq 15 into a new token 985
# merging (338, 286) with freq 15 into a new token 986
# merging (440, 271) with freq 15 into a new token 987
# merging (405, 299) with freq 15 into a new token 988
# merging (278, 298) with freq 15 into a new token 989
# merging (331, 271) with freq 15 into a new token 990
# merging (316, 277) with freq 15 into a new token 991
# merging (403, 411) with freq 15 into a new token 992
# merging (439, 319) with freq 15 into a new token 993
# merging (343, 283) with freq 15 into a new token 994
# merging (311, 352) with freq 15 into a new token 995
# merging (594, 295) with freq 15 into a new token 996
# merging (277, 274) with freq 15 into a new token 997
# merging (282, 286) with freq 15 into a new token 998
# merging (262, 273) with freq 15 into a new token 999
# merging (291, 280) with freq 15 into a new token 1000
# merging (290, 143) with freq 15 into a new token 1001
# merging (275, 159) with freq 15 into a new token 1002
# merging (257, 160) with freq 15 into a new token 1003
# merging (282, 308) with freq 15 into a new token 1004
# merging (313, 184) with freq 15 into a new token 1005
# merging (387, 284) with freq 15 into a new token 1006
# merging (314, 284) with freq 15 into a new token 1007
# merging (408, 435) with freq 15 into a new token 1008
# merging (258, 395) with freq 15 into a new token 1009
# merging (456, 294) with freq 15 into a new token 1010
# merging (328, 492) with freq 15 into a new token 1011
# merging (258, 345) with freq 15 into a new token 1012
# merging (326, 258) with freq 14 into a new token 1013
# merging (359, 181) with freq 14 into a new token 1014
# merging (270, 159) with freq 14 into a new token 1015
# merging (443, 184) with freq 14 into a new token 1016
# merging (275, 595) with freq 14 into a new token 1017
# merging (266, 717) with freq 14 into a new token 1018
# merging (359, 166) with freq 14 into a new token 1019
# merging (331, 285) with freq 14 into a new token 1020
# merging (297, 384) with freq 14 into a new token 1021
# merging (280, 277) with freq 14 into a new token 1022
# merging (278, 370) with freq 14 into a new token 1023
# merging (268, 307) with freq 14 into a new token 1024
# merging (269, 134) with freq 14 into a new token 1025
# merging (275, 581) with freq 14 into a new token 1026
# merging (313, 149) with freq 14 into a new token 1027
# merging (282, 327) with freq 14 into a new token 1028
# merging (278, 260) with freq 14 into a new token 1029
# merging (280, 297) with freq 14 into a new token 1030
# merging (279, 284) with freq 14 into a new token 1031
# merging (262, 271) with freq 14 into a new token 1032
# merging (289, 603) with freq 14 into a new token 1033
# merging (522, 281) with freq 14 into a new token 1034
# merging (268, 430) with freq 14 into a new token 1035
# merging (332, 286) with freq 14 into a new token 1036
# merging (352, 302) with freq 14 into a new token 1037
# merging (494, 262) with freq 14 into a new token 1038
# merging (281, 272) with freq 14 into a new token 1039
# merging (276, 324) with freq 14 into a new token 1040
# merging (403, 271) with freq 14 into a new token 1041
# merging (271, 301) with freq 14 into a new token 1042
# merging (291, 322) with freq 14 into a new token 1043
# merging (136, 272) with freq 14 into a new token 1044
# merging (261, 420) with freq 14 into a new token 1045
# merging (312, 176) with freq 14 into a new token 1046
# merging (256, 163) with freq 14 into a new token 1047
# merging (257, 181) with freq 14 into a new token 1048
# merging (274, 271) with freq 14 into a new token 1049
# merging (312, 164) with freq 14 into a new token 1050
# merging (293, 151) with freq 14 into a new token 1051
# merging (365, 280) with freq 14 into a new token 1052
# merging (263, 152) with freq 14 into a new token 1053
# merging (384, 271) with freq 14 into a new token 1054
# merging (292, 322) with freq 14 into a new token 1055
# merging (282, 367) with freq 14 into a new token 1056
# merging (275, 307) with freq 14 into a new token 1057
# merging (550, 280) with freq 14 into a new token 1058
# merging (323, 286) with freq 14 into a new token 1059
# merging (515, 296) with freq 14 into a new token 1060
# merging (273, 287) with freq 13 into a new token 1061
# merging (264, 150) with freq 13 into a new token 1062
# merging (276, 346) with freq 13 into a new token 1063
# merging (423, 308) with freq 13 into a new token 1064
# merging (332, 274) with freq 13 into a new token 1065
# merging (292, 302) with freq 13 into a new token 1066
# merging (330, 259) with freq 13 into a new token 1067
# merging (311, 260) with freq 13 into a new token 1068
# merging (266, 160) with freq 13 into a new token 1069
# merging (359, 167) with freq 13 into a new token 1070
# merging (283, 349) with freq 13 into a new token 1071
# merging (413, 285) with freq 13 into a new token 1072
# merging (497, 137) with freq 13 into a new token 1073
# merging (314, 260) with freq 13 into a new token 1074
# merging (283, 262) with freq 13 into a new token 1075
# merging (399, 274) with freq 13 into a new token 1076
# merging (394, 260) with freq 13 into a new token 1077
# merging (366, 309) with freq 13 into a new token 1078
# merging (278, 319) with freq 13 into a new token 1079
# merging (287, 259) with freq 13 into a new token 1080
# merging (353, 259) with freq 13 into a new token 1081
# merging (299, 289) with freq 13 into a new token 1082
# merging (389, 286) with freq 13 into a new token 1083
# merging (301, 296) with freq 13 into a new token 1084
# merging (538, 274) with freq 13 into a new token 1085
# merging (272, 308) with freq 13 into a new token 1086
# merging (347, 259) with freq 13 into a new token 1087
# merging (278, 446) with freq 13 into a new token 1088
# merging (288, 437) with freq 13 into a new token 1089
# merging (342, 274) with freq 13 into a new token 1090
# merging (311, 309) with freq 13 into a new token 1091
# merging (279, 326) with freq 13 into a new token 1092
# merging (314, 281) with freq 13 into a new token 1093
# merging (290, 138) with freq 13 into a new token 1094
# merging (365, 274) with freq 13 into a new token 1095
# merging (844, 1047) with freq 13 into a new token 1096
# merging (340, 274) with freq 13 into a new token 1097
# merging (497, 133) with freq 13 into a new token 1098
# merging (447, 280) with freq 13 into a new token 1099
# merging (328, 183) with freq 13 into a new token 1100
# merging (463, 260) with freq 13 into a new token 1101
# merging (317, 151) with freq 13 into a new token 1102
# merging (516, 420) with freq 13 into a new token 1103
# merging (318, 135) with freq 13 into a new token 1104
# merging (325, 183) with freq 13 into a new token 1105
# merging (317, 149) with freq 13 into a new token 1106
# merging (484, 273) with freq 13 into a new token 1107
# merging (331, 346) with freq 13 into a new token 1108
# merging (311, 273) with freq 13 into a new token 1109
# merging (319, 282) with freq 13 into a new token 1110
# merging (279, 333) with freq 13 into a new token 1111
# merging (288, 435) with freq 13 into a new token 1112
# merging (323, 259) with freq 13 into a new token 1113
# merging (318, 151) with freq 13 into a new token 1114
# merging (182, 420) with freq 13 into a new token 1115
# merging (335, 285) with freq 13 into a new token 1116
# merging (324, 272) with freq 12 into a new token 1117
# merging (258, 354) with freq 12 into a new token 1118
# merging (274, 298) with freq 12 into a new token 1119
# merging (323, 421) with freq 12 into a new token 1120
# merging (308, 284) with freq 12 into a new token 1121
# merging (339, 137) with freq 12 into a new token 1122
# merging (497, 135) with freq 12 into a new token 1123
# merging (305, 808) with freq 12 into a new token 1124
# merging (338, 310) with freq 12 into a new token 1125
# merging (283, 344) with freq 12 into a new token 1126
# merging (330, 262) with freq 12 into a new token 1127
# merging (291, 319) with freq 12 into a new token 1128
# merging (268, 152) with freq 12 into a new token 1129
# merging (340, 272) with freq 12 into a new token 1130
# merging (278, 273) with freq 12 into a new token 1131
# merging (318, 167) with freq 12 into a new token 1132
# merging (278, 281) with freq 12 into a new token 1133
# merging (305, 149) with freq 12 into a new token 1134
# merging (261, 395) with freq 12 into a new token 1135
# merging (316, 285) with freq 12 into a new token 1136
# merging (290, 181) with freq 12 into a new token 1137
# merging (263, 575) with freq 12 into a new token 1138
# merging (410, 174) with freq 12 into a new token 1139
# merging (288, 395) with freq 12 into a new token 1140
# merging (410, 170) with freq 12 into a new token 1141
# merging (370, 261) with freq 12 into a new token 1142
# merging (387, 271) with freq 12 into a new token 1143
# merging (429, 299) with freq 12 into a new token 1144
# merging (361, 259) with freq 12 into a new token 1145
# merging (344, 272) with freq 12 into a new token 1146
# merging (292, 299) with freq 12 into a new token 1147
# merging (279, 354) with freq 12 into a new token 1148
# merging (563, 304) with freq 12 into a new token 1149
# merging (417, 284) with freq 12 into a new token 1150
# merging (474, 184) with freq 12 into a new token 1151
# merging (258, 332) with freq 12 into a new token 1152
# merging (362, 149) with freq 12 into a new token 1153
# ...
# merging (424, 2431) with freq 2 into a new token 4201
# merging (4201, 835) with freq 2 into a new token 4202
# merging (284, 3031) with freq 2 into a new token 4203
# merging (672, 303) with freq 2 into a new token 4204
# merging (424, 907) with freq 2 into a new token 4205
# merging (273, 523) with freq 2 into a new token 4206
# merging (296, 712) with freq 2 into a new token 4207
# merging (321, 152) with freq 2 into a new token 4208
# merging (297, 948) with freq 2 into a new token 4209
# merging (427, 3035) with freq 2 into a new token 4210
# merging (340, 276) with freq 2 into a new token 4211
# merging (333, 431) with freq 2 into a new token 4212
# merging (392, 388) with freq 2 into a new token 4213
# merging (334, 841) with freq 2 into a new token 4214
# merging (1119, 300) with freq 2 into a new token 4215
# merging (275, 152) with freq 2 into a new token 4216
# merging (369, 556) with freq 2 into a new token 4217
# merging (326, 592) with freq 2 into a new token 4218
# merging (289, 282) with freq 2 into a new token 4219
# merging (398, 276) with freq 2 into a new token 4220
# merging (1538, 299) with freq 2 into a new token 4221
# merging (432, 1229) with freq 2 into a new token 4222
# merging (291, 701) with freq 2 into a new token 4223
# merging (344, 627) with freq 2 into a new token 4224
# merging (419, 3039) with freq 2 into a new token 4225
# merging (589, 455) with freq 2 into a new token 4226
# merging (285, 343) with freq 2 into a new token 4227
# merging (2438, 382) with freq 2 into a new token 4228
# merging (370, 455) with freq 2 into a new token 4229
# merging (848, 422) with freq 2 into a new token 4230
# merging (329, 395) with freq 2 into a new token 4231
# merging (515, 285) with freq 2 into a new token 4232
# merging (471, 292) with freq 2 into a new token 4233
# merging (660, 330) with freq 2 into a new token 4234
# merging (318, 267) with freq 2 into a new token 4235
# merging (1357, 284) with freq 2 into a new token 4236
# merging (519, 315) with freq 2 into a new token 4237
# merging (261, 2440) with freq 2 into a new token 4238
# merging (452, 922) with freq 2 into a new token 4239
# merging (448, 338) with freq 2 into a new token 4240
# merging (2067, 487) with freq 2 into a new token 4241
# merging (422, 451) with freq 2 into a new token 4242
# merging (617, 2442) with freq 2 into a new token 4243
# merging (269, 307) with freq 2 into a new token 4244
# merging (301, 1188) with freq 2 into a new token 4245
# merging (1302, 423) with freq 2 into a new token 4246
# merging (491, 376) with freq 2 into a new token 4247
# merging (353, 926) with freq 2 into a new token 4248
# merging (455, 457) with freq 2 into a new token 4249
# merging (273, 297) with freq 2 into a new token 4250
# merging (952, 274) with freq 2 into a new token 4251
# merging (276, 293) with freq 2 into a new token 4252
# merging (291, 3066) with freq 2 into a new token 4253
# merging (4253, 716) with freq 2 into a new token 4254
# merging (432, 487) with freq 2 into a new token 4255
# merging (746, 289) with freq 2 into a new token 4256
# merging (281, 262) with freq 2 into a new token 4257
# merging (303, 812) with freq 2 into a new token 4258
# merging (510, 1493) with freq 2 into a new token 4259
# merging (409, 1519) with freq 2 into a new token 4260
# merging (1233, 274) with freq 2 into a new token 4261
# merging (659, 355) with freq 2 into a new token 4262
# merging (480, 1234) with freq 2 into a new token 4263
# merging (280, 519) with freq 2 into a new token 4264
# merging (723, 1874) with freq 2 into a new token 4265
# merging (262, 613) with freq 2 into a new token 4266
# merging (792, 277) with freq 2 into a new token 4267
# merging (352, 947) with freq 2 into a new token 4268
# merging (505, 259) with freq 2 into a new token 4269
# merging (309, 303) with freq 2 into a new token 4270
# merging (502, 167) with freq 2 into a new token 4271
# merging (284, 423) with freq 2 into a new token 4272
# merging (351, 716) with freq 2 into a new token 4273
# merging (566, 560) with freq 2 into a new token 4274
# merging (1233, 259) with freq 2 into a new token 4275
# merging (551, 3075) with freq 2 into a new token 4276
# merging (404, 279) with freq 2 into a new token 4277
# merging (965, 346) with freq 2 into a new token 4278
# merging (332, 646) with freq 2 into a new token 4279
# merging (402, 272) with freq 2 into a new token 4280
# merging (286, 573) with freq 2 into a new token 4281
# merging (1219, 279) with freq 2 into a new token 4282
# merging (283, 679) with freq 2 into a new token 4283
# merging (1681, 298) with freq 2 into a new token 4284
# merging (312, 662) with freq 2 into a new token 4285
# merging (402, 322) with freq 2 into a new token 4286
# merging (951, 895) with freq 2 into a new token 4287
# merging (878, 279) with freq 2 into a new token 4288
# merging (333, 1833) with freq 2 into a new token 4289
# merging (1649, 795) with freq 2 into a new token 4290
# merging (458, 1877) with freq 2 into a new token 4291
# merging (1268, 750) with freq 2 into a new token 4292
# merging (606, 261) with freq 2 into a new token 4293
# merging (665, 300) with freq 2 into a new token 4294
# merging (1875, 382) with freq 2 into a new token 4295
# merging (2994, 1055) with freq 2 into a new token 4296
# merging (261, 774) with freq 2 into a new token 4297
# merging (285, 259) with freq 2 into a new token 4298
# merging (289, 1399) with freq 2 into a new token 4299
# merging (928, 462) with freq 2 into a new token 4300
# merging (413, 352) with freq 2 into a new token 4301
# merging (311, 611) with freq 2 into a new token 4302
# merging (4302, 1169) with freq 2 into a new token 4303
# merging (337, 496) with freq 2 into a new token 4304
# merging (281, 1400) with freq 2 into a new token 4305
# merging (547, 353) with freq 2 into a new token 4306
# merging (862, 342) with freq 2 into a new token 4307
# merging (298, 788) with freq 2 into a new token 4308
# merging (463, 861) with freq 2 into a new token 4309
# merging (289, 2465) with freq 2 into a new token 4310
# merging (908, 849) with freq 2 into a new token 4311
# merging (288, 268) with freq 2 into a new token 4312
# merging (271, 286) with freq 2 into a new token 4313
# merging (634, 288) with freq 2 into a new token 4314
# merging (425, 420) with freq 2 into a new token 4315
# merging (526, 326) with freq 2 into a new token 4316
# merging (738, 276) with freq 2 into a new token 4317
# merging (415, 415) with freq 2 into a new token 4318
# merging (390, 283) with freq 2 into a new token 4319
# merging (762, 280) with freq 2 into a new token 4320
# merging (386, 1009) with freq 2 into a new token 4321
# merging (283, 1517) with freq 2 into a new token 4322
# merging (585, 495) with freq 2 into a new token 4323
# merging (574, 276) with freq 2 into a new token 4324
# merging (281, 284) with freq 2 into a new token 4325
# merging (1406, 2854) with freq 2 into a new token 4326
# merging (331, 526) with freq 2 into a new token 4327
# merging (351, 310) with freq 2 into a new token 4328
# merging (279, 1637) with freq 2 into a new token 4329
# merging (669, 2117) with freq 2 into a new token 4330
# merging (353, 2127) with freq 2 into a new token 4331
# merging (383, 138) with freq 2 into a new token 4332
# merging (433, 1515) with freq 2 into a new token 4333
# merging (280, 274) with freq 2 into a new token 4334
# merging (374, 331) with freq 2 into a new token 4335
# merging (345, 1884) with freq 2 into a new token 4336
# merging (361, 1169) with freq 2 into a new token 4337
# merging (425, 1652) with freq 2 into a new token 4338
# merging (262, 2474) with freq 2 into a new token 4339
# merging (477, 271) with freq 2 into a new token 4340
# merging (387, 722) with freq 2 into a new token 4341
# merging (1548, 680) with freq 2 into a new token 4342
# merging (314, 276) with freq 2 into a new token 4343
# merging (369, 283) with freq 2 into a new token 4344
# merging (1987, 311) with freq 2 into a new token 4345
# merging (426, 264) with freq 2 into a new token 4346
# merging (291, 337) with freq 2 into a new token 4347
# merging (521, 1474) with freq 2 into a new token 4348
# merging (4348, 337) with freq 2 into a new token 4349
# merging (550, 496) with freq 2 into a new token 4350
# merging (418, 283) with freq 2 into a new token 4351
# merging (389, 1886) with freq 2 into a new token 4352
# merging (287, 693) with freq 2 into a new token 4353
# merging (1048, 304) with freq 2 into a new token 4354
# merging (337, 452) with freq 2 into a new token 4355
# merging (551, 472) with freq 2 into a new token 4356
# merging (289, 327) with freq 2 into a new token 4357
# merging (530, 673) with freq 2 into a new token 4358
# merging (338, 1239) with freq 2 into a new token 4359
# merging (1520, 376) with freq 2 into a new token 4360
# merging (1290, 385) with freq 2 into a new token 4361
# merging (4361, 271) with freq 2 into a new token 4362
# merging (319, 298) with freq 2 into a new token 4363
# merging (733, 274) with freq 2 into a new token 4364
# merging (404, 913) with freq 2 into a new token 4365
# merging (351, 753) with freq 2 into a new token 4366
# merging (480, 427) with freq 2 into a new token 4367
# merging (882, 1690) with freq 2 into a new token 4368
# merging (337, 331) with freq 2 into a new token 4369
# merging (553, 283) with freq 2 into a new token 4370
# merging (261, 769) with freq 2 into a new token 4371
# merging (1144, 507) with freq 2 into a new token 4372
# merging (669, 526) with freq 2 into a new token 4373
# merging (277, 343) with freq 2 into a new token 4374
# merging (429, 356) with freq 2 into a new token 4375
# merging (315, 840) with freq 2 into a new token 4376
# merging (901, 969) with freq 2 into a new token 4377
# merging (380, 535) with freq 2 into a new token 4378
# merging (312, 2132) with freq 2 into a new token 4379
# merging (600, 813) with freq 2 into a new token 4380
# merging (3125, 759) with freq 2 into a new token 4381
# merging (343, 558) with freq 2 into a new token 4382
# merging (449, 316) with freq 2 into a new token 4383
# merging (495, 279) with freq 2 into a new token 4384
# merging (1853, 282) with freq 2 into a new token 4385
# merging (345, 298) with freq 2 into a new token 4386
# merging (303, 294) with freq 2 into a new token 4387
# merging (449, 2486) with freq 2 into a new token 4388
# merging (368, 387) with freq 2 into a new token 4389
# merging (481, 448) with freq 2 into a new token 4390
# merging (835, 697) with freq 2 into a new token 4391
# merging (393, 1227) with freq 2 into a new token 4392
# merging (1878, 543) with freq 2 into a new token 4393
# merging (992, 377) with freq 2 into a new token 4394
# merging (390, 487) with freq 2 into a new token 4395
# merging (432, 721) with freq 2 into a new token 4396
# merging (507, 530) with freq 2 into a new token 4397
# merging (301, 897) with freq 2 into a new token 4398
# merging (4398, 506) with freq 2 into a new token 4399
# merging (542, 1162) with freq 2 into a new token 4400
# merging (363, 621) with freq 2 into a new token 4401
# merging (270, 181) with freq 2 into a new token 4402
# merging (429, 1411) with freq 2 into a new token 4403
# merging (4403, 1209) with freq 2 into a new token 4404
# merging (386, 679) with freq 2 into a new token 4405
# merging (392, 3145) with freq 2 into a new token 4406
# merging (299, 530) with freq 2 into a new token 4407
# merging (1693, 804) with freq 2 into a new token 4408
# merging (276, 1291) with freq 2 into a new token 4409
# merging (463, 451) with freq 2 into a new token 4410
# merging (838, 773) with freq 2 into a new token 4411
# merging (289, 337) with freq 2 into a new token 4412
# merging (1873, 388) with freq 2 into a new token 4413
# merging (839, 2140) with freq 2 into a new token 4414
# merging (523, 527) with freq 2 into a new token 4415
# merging (381, 300) with freq 2 into a new token 4416
# merging (553, 356) with freq 2 into a new token 4417
# merging (498, 351) with freq 2 into a new token 4418
# merging (323, 276) with freq 2 into a new token 4419
# merging (271, 332) with freq 2 into a new token 4420
# merging (4420, 332) with freq 2 into a new token 4421
# merging (718, 330) with freq 2 into a new token 4422
# merging (496, 427) with freq 2 into a new token 4423
# merging (2141, 295) with freq 2 into a new token 4424
# merging (276, 651) with freq 2 into a new token 4425
# merging (461, 573) with freq 2 into a new token 4426
# merging (289, 279) with freq 2 into a new token 4427
# merging (1073, 718) with freq 2 into a new token 4428
# merging (646, 319) with freq 2 into a new token 4429
# merging (1221, 333) with freq 2 into a new token 4430
# merging (972, 670) with freq 2 into a new token 4431
# merging (725, 353) with freq 2 into a new token 4432
# merging (287, 1609) with freq 2 into a new token 4433
# merging (387, 300) with freq 2 into a new token 4434
# merging (1298, 774) with freq 2 into a new token 4435
# merging (405, 326) with freq 2 into a new token 4436
# merging (1540, 340) with freq 2 into a new token 4437
# merging (1895, 165) with freq 2 into a new token 4438
# merging (282, 1313) with freq 2 into a new token 4439
# merging (1019, 711) with freq 2 into a new token 4440
# merging (261, 363) with freq 2 into a new token 4441
# merging (522, 271) with freq 2 into a new token 4442
# merging (332, 375) with freq 2 into a new token 4443
# merging (481, 387) with freq 2 into a new token 4444
# merging (391, 386) with freq 2 into a new token 4445
# merging (356, 291) with freq 2 into a new token 4446
# merging (377, 630) with freq 2 into a new token 4447
# merging (278, 964) with freq 2 into a new token 4448
# merging (429, 874) with freq 2 into a new token 4449
# merging (299, 439) with freq 2 into a new token 4450
# merging (280, 262) with freq 2 into a new token 4451
# merging (1534, 314) with freq 2 into a new token 4452
# merging (666, 408) with freq 2 into a new token 4453
# merging (3159, 1896) with freq 2 into a new token 4454
# merging (296, 500) with freq 2 into a new token 4455
# merging (1269, 281) with freq 2 into a new token 4456
# merging (4456, 271) with freq 2 into a new token 4457
# merging (294, 560) with freq 2 into a new token 4458
# merging (276, 860) with freq 2 into a new token 4459
# merging (278, 457) with freq 2 into a new token 4460
# merging (462, 368) with freq 2 into a new token 4461
# merging (297, 329) with freq 2 into a new token 4462
# merging (262, 354) with freq 2 into a new token 4463
# merging (301, 837) with freq 2 into a new token 4464
# merging (462, 340) with freq 2 into a new token 4465
# merging (491, 279) with freq 2 into a new token 4466
# merging (424, 338) with freq 2 into a new token 4467
# merging (427, 543) with freq 2 into a new token 4468
# merging (415, 262) with freq 2 into a new token 4469
# merging (481, 381) with freq 2 into a new token 4470
# merging (549, 271) with freq 2 into a new token 4471
# merging (954, 465) with freq 2 into a new token 4472
# merging (289, 2513) with freq 2 into a new token 4473
# merging (279, 2514) with freq 2 into a new token 4474
# merging (444, 751) with freq 2 into a new token 4475
# merging (289, 908) with freq 2 into a new token 4476
# merging (369, 480) with freq 2 into a new token 4477
# merging (412, 3172) with freq 2 into a new token 4478
# merging (2093, 859) with freq 2 into a new token 4479
# merging (355, 324) with freq 2 into a new token 4480
# merging (652, 587) with freq 2 into a new token 4481
# merging (504, 272) with freq 2 into a new token 4482
# merging (1899, 380) with freq 2 into a new token 4483
# merging (2152, 501) with freq 2 into a new token 4484
# merging (278, 973) with freq 2 into a new token 4485
# merging (666, 2518) with freq 2 into a new token 4486
# merging (4486, 1614) with freq 2 into a new token 4487
# merging (419, 914) with freq 2 into a new token 4488
# merging (363, 354) with freq 2 into a new token 4489
# merging (875, 289) with freq 2 into a new token 4490
# merging (1041, 277) with freq 2 into a new token 4491
# merging (506, 395) with freq 2 into a new token 4492
# merging (579, 301) with freq 2 into a new token 4493
# merging (458, 137) with freq 2 into a new token 4494
# merging (3177, 484) with freq 2 into a new token 4495
# merging (392, 273) with freq 2 into a new token 4496
# merging (1062, 2047) with freq 2 into a new token 4497
# merging (918, 461) with freq 2 into a new token 4498
# merging (985, 273) with freq 2 into a new token 4499

# %%
print("tokens length:", len(tokens))
print("ids length:", len(ids))
print(f"compression ratio: {len(tokens) / len(ids):.2f}X")
# Out:
# tokens length: 327965
# ids length: 38829
# compression ratio: 8.45X
