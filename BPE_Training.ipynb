# %%
with open('hindilit.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print("the length of the data is: ", len(text))
print("the first 1000:", text[:1000])
# Out:
# the length of the data is:  198222
# the first 1000: जो सुमिरत सिधि होइ गन नायक करिबर बदन।
# करउ अनुग्रह सोइ बुद्धि रासि सुभ गुन सदन॥1॥
# मूक होइ बाचाल पंगु चढइ गिरिबर गहन।
# जासु कृपाँ सो दयाल द्रवउ सकल कलि मल दहन॥2॥
# नील सरोरुह स्याम तरुन अरुन बारिज नयन।
# करउ सो मम उर धाम सदा छीरसागर सयन॥3॥
# कुंद इंदु सम देह उमा रमन करुना अयन।
# जाहि दीन पर नेह करउ कृपा मर्दन मयन॥4॥
# बंदउ गुरु पद कंज कृपा सिंधु नररूप हरि।
# महामोह तम पुंज जासु बचन रबि कर निकर॥5॥
# बंदउ गुरु पद पदुम परागा। सुरुचि सुबास सरस अनुरागा॥
# अमिय मूरिमय चूरन चारू। समन सकल भव रुज परिवारू॥
# सुकृति संभु तन बिमल बिभूती। मंजुल मंगल मोद प्रसूती॥
# जन मन मंजु मुकुर मल हरनी। किएँ तिलक गुन गन बस करनी॥
# श्रीगुर पद नख मनि गन जोती। सुमिरत दिब्य द्रृष्टि हियँ होती॥
# दलन मोह तम सो सप्रकासू। बड़े भाग उर आवइ जासू॥
# उघरहिं बिमल बिलोचन ही के। मिटहिं दोष दुख भव रजनी के॥
# सूझहिं राम चरित मनि मानिक। गुपुत प्रगट जहँ जो जेहि खानिक॥
# दो0-जथा सुअंजन अंजि दृग साधक सिद्ध सुजान।
# कौतुक देखत सैल बन भूतल भूरि निधान॥1॥
#
# एहि महँ रघुपति नाम उदारा। अति पावन पुरान श्रुति सारा॥
# मंगल भवन अमंगल हारी। उमा सहित जेहि जपत पुरारी॥
# भनिति बिचित्र स

# %%
normalization_dict = {
    # Variants of "मैं" (I)
    'मै': 'मैं',
    'मुझको': 'मुझे',
    'मुझसे': 'मुझे',
    'मैने': 'मैंने',

    # Variants of "यहाँ" (here) and "वहाँ" (there)
    'यहा': 'यहाँ',
    'वहा': 'वहाँ',

    # Variants of "क्यों" (why) and related forms
    'क्यु': 'क्यों',
    'क्युकी': 'क्योंकि',
    'क्यू': 'क्यों',

    # Variants of "तुम्हें" (you)
    'तुम्हे': 'तुम्हें',
    'तुमको': 'तुम्हें',

    # Variants of "हमें" (us)
    'हमको': 'हमें',
    'हमसे': 'हमें',

    # Variants of "करूं" (I do)
    'करु': 'करूं',
    'करूँ': 'करूं',  # Alternate Unicode representation

    # Variants of "गए" (went)
    'गये': 'गए',

    # Variants of "पढ़ाई" (study)
    'पढाई': 'पढ़ाई',
    'पढना': 'पढ़ना',

    # Casual/phonetic forms
    'कैसा': 'कैसे',  # Normalize gender-neutral "कैसे"
    'किसे': 'किसे',  # Sometimes used as "किसको"
    'जो': 'जो',  # Ensure no typo between "जो" and "झो"

    # Variants of common auxiliary verbs
    'हू': 'हूँ',
    'हैं': 'है',  # Simplify plural to singular for some cases
    'था': 'थे',  # Normalize tense differences
    'थी': 'थे',

    # Typo corrections
    'और': 'और',
    'से': 'से',
    'तो': 'तो',

}

# %%
import re

#Normalizing Orthographic Variations
for key, value in normalization_dict.items():
  # Replace variations using regex
  text = re.sub(r'\b' + re.escape(key) + r'\b', value, text)

#Compound words separated
# Replace hyphen-separated or underscore-separated compounds with space-separated words
text = re.sub(r'(\w+)[-_](\w+)', r'\1 \2', text)
# Replace other compound connectors (e.g., dots in specific cases)
text = re.sub(r'(\w+)\.(\w+)', r'\1 \2', text)

#Final cleaning of non-hindi characters
# Remove non-Devanagari characters and non-space characters
cleaned_text = re.sub(r'[^अ-ह\s]', '', text)

#Finally removing unecessary spaces and making it all one line
cleaned_text = re.sub(r'\s+', ' ', text).strip()  # Replace multiple spaces with a single space
print(cleaned_text[:1000])  # Output: "नमस्ते  है"
# Out:
# जो सुमिरत सिधि होइ गन नायक करिबर बदन। करउ अनुग्रह सोइ बुद्धि रासि सुभ गुन सदन॥1॥ मूक होइ बाचाल पंगु चढइ गिरिबर गहन। जासु कृपाँ सो दयाल द्रवउ सकल कलि मल दहन॥2॥ नील सरोरुह स्याम तरुन अरुन बारिज नयन। करउ सो मम उर धाम सदा छीरसागर सयन॥3॥ कुंद इंदु सम देह उमा रमन करूंना अयन। जाहि दीन पर नेह करउ कृपा मर्दन मयन॥4॥ बंदउ गुरु पद कंज कृपा सिंधु नररूप हरि। महामोह तम पुंज जासु बचन रबि कर निकर॥5॥ बंदउ गुरु पद पदुम परागा। सुरुचि सुबास सरस अनुरागा॥ अमिय मूरिमय चूरन चारू। समन सकल भव रुज परिवारू॥ सुकृति संभु तन बिमल बिभूती। मंजुल मंगल मोद प्रसूती॥ जन मन मंजु मुकुर मल हरनी। किएँ तिलक गुन गन बस करनी॥ श्रीगुर पद नख मनि गन जोती। सुमिरत दिब्य द्रृष्टि हियँ होती॥ दलन मोह तम सो सप्रकासू। बड़े भाग उर आवइ जासू॥ उघरहिं बिमल बिलोचन ही के। मिटहिं दोष दुख भव रजनी के॥ सूझहिं राम चरित मनि मानिक। गुपुत प्रगट जहँ जो जेहि खानिक॥ दो0 जथा सुअंजन अंजि दृग साधक सिद्ध सुजान। कौतुक देखत सैल बन भूतल भूरि निधान॥1॥ एहि महँ रघुपति नाम उदारा। अति पावन पुरान श्रुति सारा॥ मंगल भवन अमंगल हारी। उमा सहित जेहि जपत पुरारी॥ भनिति बिचित्र स

# %%
chars = sorted(list(set(cleaned_text)))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)
# Out:
#  (),-0123456789ûँंःअआइईउऊएऐओऔकखगघङचछजझटठडढणतथदधनपफबभमयरलवशषसह़ऽािीुूृेैोौ्।॥०१२३४५६७८९
# 86

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# %%
tokens = cleaned_text.encode("utf-8") # raw bytes
tokens = list(map(int, tokens)) # convert to a list of integers in range 0..255 for convenience

# %%
#Making pairs and getting a count
def get_stats(ids):
    counts = {}
    for pair in zip(ids, ids[1:]):
        counts[pair] = counts.get(pair, 0) + 1
    return counts
#Merging the given pair and giving it a new index
def merge(ids, pair, idx):
  newids = []
  i = 0
  while i < len(ids):
    if i < len(ids) - 1 and ids[i] == pair[0] and ids[i+1] == pair[1]:
      newids.append(idx)
      i += 2
    else:
      newids.append(ids[i])
      i += 1
  return newids

# %%
# ---
vocab_size = 4500 # the desired final vocabulary size
num_merges = vocab_size - 256
ids = list(tokens) # copy so we don't destroy the original list

merges = {} # (int, int) -> int
for i in range(num_merges):
  stats = get_stats(ids)
  pair = max(stats, key=stats.get)
  idx = 256 + i
  print(f"merging {pair} with freq {stats[pair]} into a new token {idx}")
  ids = merge(ids, pair, idx)
  merges[pair] = idx
# Out:
# merging (224, 164) with freq 126416 into a new token 256
# merging (32, 256) with freq 37331 into a new token 257
# merging (224, 165) with freq 32686 into a new token 258
# merging (256, 190) with freq 12178 into a new token 259
# merging (256, 191) with freq 12068 into a new token 260
# merging (259, 256) with freq 9131 into a new token 261
# merging (258, 129) with freq 7832 into a new token 262
# merging (256, 176) with freq 7691 into a new token 263
# merging (260, 256) with freq 6100 into a new token 264
# merging (257, 184) with freq 5745 into a new token 265
# merging (256, 185) with freq 5710 into a new token 266
# merging (256, 168) with freq 5525 into a new token 267
# merging (260, 257) with freq 4490 into a new token 268
# merging (164, 257) with freq 4296 into a new token 269
# merging (258, 165) with freq 4142 into a new token 270
# merging (258, 128) with freq 3892 into a new token 271
# merging (258, 135) with freq 3846 into a new token 272
# merging (258, 141) with freq 3451 into a new token 273
# merging (258, 139) with freq 3042 into a new token 274
# merging (270, 257) with freq 3011 into a new token 275
# merging (262, 256) with freq 3004 into a new token 276
# merging (258, 269) with freq 2938 into a new token 277
# merging (257, 172) with freq 2689 into a new token 278
# merging (256, 130) with freq 2507 into a new token 279
# merging (257, 149) with freq 2319 into a new token 280
# merging (256, 164) with freq 2071 into a new token 281
# merging (256, 184) with freq 1809 into a new token 282
# merging (256, 178) with freq 1790 into a new token 283
# merging (257, 174) with freq 1754 into a new token 284
# merging (256, 149) with freq 1669 into a new token 285
# merging (257, 170) with freq 1658 into a new token 286
# merging (256, 174) with freq 1598 into a new token 287
# merging (257, 156) with freq 1506 into a new token 288
# merging (257, 168) with freq 1496 into a new token 289
# merging (261, 168) with freq 1490 into a new token 290
# merging (273, 263) with freq 1459 into a new token 291
# merging (261, 176) with freq 1393 into a new token 292
# merging (256, 175) with freq 1292 into a new token 293
# merging (256, 166) with freq 1272 into a new token 294
# merging (256, 172) with freq 1268 into a new token 295
# merging (256, 151) with freq 1265 into a new token 296
# merging (256, 170) with freq 1265 into a new token 297
# merging (256, 181) with freq 1170 into a new token 298
# merging (258, 130) with freq 1152 into a new token 299
# merging (262, 267) with freq 1143 into a new token 300
# merging (266, 264) with freq 1113 into a new token 301
# merging (257, 133) with freq 1061 into a new token 302
# merging (278, 264) with freq 920 into a new token 303
# merging (274, 256) with freq 915 into a new token 304
# merging (257, 164) with freq 886 into a new token 305
# merging (257, 166) with freq 872 into a new token 306
# merging (301, 130) with freq 866 into a new token 307
# merging (265, 276) with freq 863 into a new token 308
# merging (259, 277) with freq 861 into a new token 309
# merging (257, 173) with freq 860 into a new token 310
# merging (273, 266) with freq 859 into a new token 311
# merging (257, 176) with freq 846 into a new token 312
# merging (261, 174) with freq 823 into a new token 313
# merging (256, 129) with freq 819 into a new token 314
# merging (259, 275) with freq 799 into a new token 315
# merging (272, 256) with freq 782 into a new token 316
# merging (266, 268) with freq 746 into a new token 317
# merging (262, 263) with freq 744 into a new token 318
# merging (281, 268) with freq 705 into a new token 319
# merging (260, 265) with freq 685 into a new token 320
# merging (256, 269) with freq 663 into a new token 321
# merging (257, 151) with freq 655 into a new token 322
# merging (256, 156) with freq 641 into a new token 323
# merging (257, 185) with freq 632 into a new token 324
# merging (258, 131) with freq 620 into a new token 325
# merging (271, 277) with freq 580 into a new token 326
# merging (261, 136) with freq 568 into a new token 327
# merging (164, 265) with freq 556 into a new token 328
# merging (271, 275) with freq 551 into a new token 329
# merging (256, 154) with freq 532 into a new token 330
# merging (261, 185) with freq 531 into a new token 331
# merging (271, 279) with freq 526 into a new token 332
# merging (260, 263) with freq 518 into a new token 333
# merging (172, 264) with freq 515 into a new token 334
# merging (256, 173) with freq 506 into a new token 335
# merging (286, 291) with freq 505 into a new token 336
# merging (258, 136) with freq 503 into a new token 337
# merging (257, 178) with freq 493 into a new token 338
# merging (267, 311) with freq 490 into a new token 339
# merging (263, 268) with freq 452 into a new token 340
# merging (261, 181) with freq 450 into a new token 341
# merging (258, 328) with freq 449 into a new token 342
# merging (256, 167) with freq 438 into a new token 343
# merging (270, 265) with freq 438 into a new token 344
# merging (273, 293) with freq 437 into a new token 345
# merging (300, 268) with freq 437 into a new token 346
# merging (266, 262) with freq 420 into a new token 347
# merging (257, 154) with freq 415 into a new token 348
# merging (261, 184) with freq 403 into a new token 349
# merging (170, 291) with freq 381 into a new token 350
# merging (264, 269) with freq 376 into a new token 351
# merging (267, 262) with freq 369 into a new token 352
# merging (280, 263) with freq 361 into a new token 353
# merging (264, 168) with freq 360 into a new token 354
# merging (261, 151) with freq 357 into a new token 355
# merging (256, 150) with freq 350 into a new token 356
# merging (258, 140) with freq 349 into a new token 357
# merging (261, 156) with freq 349 into a new token 358
# merging (261, 178) with freq 348 into a new token 359
# merging (265, 295) with freq 345 into a new token 360
# merging (166, 274) with freq 343 into a new token 361
# merging (272, 279) with freq 339 into a new token 362
# merging (271, 339) with freq 331 into a new token 363
# merging (316, 150) with freq 315 into a new token 364
# merging (274, 263) with freq 309 into a new token 365
# merging (256, 137) with freq 305 into a new token 366
# merging (256, 159) with freq 304 into a new token 367
# merging (257, 134) with freq 304 into a new token 368
# merging (289, 264) with freq 303 into a new token 369
# merging (261, 164) with freq 296 into a new token 370
# merging (361, 48) with freq 295 into a new token 371
# merging (257, 167) with freq 293 into a new token 372
# merging (265, 287) with freq 293 into a new token 373
# merging (256, 165) with freq 288 into a new token 374
# merging (280, 266) with freq 287 into a new token 375
# merging (261, 135) with freq 287 into a new token 376
# merging (257, 137) with freq 280 into a new token 377
# merging (256, 183) with freq 274 into a new token 378
# merging (263, 267) with freq 271 into a new token 379
# merging (261, 129) with freq 267 into a new token 380
# merging (256, 188) with freq 267 into a new token 381
# merging (279, 296) with freq 266 into a new token 382
# merging (264, 164) with freq 256 into a new token 383
# merging (270, 258) with freq 253 into a new token 384
# merging (284, 267) with freq 252 into a new token 385
# merging (276, 174) with freq 248 into a new token 386
# merging (256, 155) with freq 247 into a new token 387
# merging (268, 149) with freq 243 into a new token 388
# merging (325, 297) with freq 241 into a new token 389
# merging (276, 129) with freq 241 into a new token 390
# merging (299, 297) with freq 236 into a new token 391
# merging (276, 178) with freq 234 into a new token 392
# merging (285, 283) with freq 227 into a new token 393
# merging (279, 294) with freq 227 into a new token 394
# merging (286, 263) with freq 227 into a new token 395
# merging (274, 266) with freq 227 into a new token 396
# merging (256, 160) with freq 223 into a new token 397
# merging (327, 277) with freq 222 into a new token 398
# merging (272, 266) with freq 221 into a new token 399
# merging (335, 262) with freq 221 into a new token 400
# merging (256, 152) with freq 221 into a new token 401
# merging (271, 263) with freq 213 into a new token 402
# merging (256, 161) with freq 210 into a new token 403
# merging (327, 275) with freq 208 into a new token 404
# merging (261, 143) with freq 207 into a new token 405
# merging (256, 135) with freq 206 into a new token 406
# merging (264, 185) with freq 200 into a new token 407
# merging (264, 175) with freq 198 into a new token 408
# merging (274, 283) with freq 195 into a new token 409
# merging (174, 267) with freq 194 into a new token 410
# merging (278, 263) with freq 193 into a new token 411
# merging (312, 313) with freq 192 into a new token 412
# merging (288, 290) with freq 192 into a new token 413
# merging (274, 285) with freq 192 into a new token 414
# merging (304, 135) with freq 190 into a new token 415
# merging (176, 313) with freq 190 into a new token 416
# merging (261, 170) with freq 187 into a new token 417
# merging (167, 268) with freq 186 into a new token 418
# merging (354, 311) with freq 186 into a new token 419
# merging (261, 175) with freq 185 into a new token 420
# merging (149, 263) with freq 185 into a new token 421
# merging (302, 267) with freq 185 into a new token 422
# merging (272, 277) with freq 185 into a new token 423
# merging (316, 137) with freq 185 into a new token 424
# merging (256, 143) with freq 183 into a new token 425
# merging (272, 317) with freq 181 into a new token 426
# merging (272, 275) with freq 180 into a new token 427
# merging (265, 279) with freq 176 into a new token 428
# merging (272, 298) with freq 175 into a new token 429
# merging (331, 332) with freq 173 into a new token 430
# merging (308, 150) with freq 173 into a new token 431
# merging (264, 149) with freq 170 into a new token 432
# merging (386, 311) with freq 168 into a new token 433
# merging (266, 314) with freq 166 into a new token 434
# merging (264, 184) with freq 165 into a new token 435
# merging (265, 263) with freq 164 into a new token 436
# merging (264, 181) with freq 160 into a new token 437
# merging (265, 300) with freq 157 into a new token 438
# merging (366, 314) with freq 157 into a new token 439
# merging (266, 390) with freq 156 into a new token 440
# merging (166, 364) with freq 155 into a new token 441
# merging (272, 281) with freq 154 into a new token 442
# merging (264, 174) with freq 149 into a new token 443
# merging (268, 172) with freq 149 into a new token 444
# merging (265, 393) with freq 147 into a new token 445
# merging (170, 263) with freq 147 into a new token 446
# merging (304, 137) with freq 145 into a new token 447
# merging (268, 168) with freq 144 into a new token 448
# merging (261, 166) with freq 143 into a new token 449
# merging (263, 378) with freq 143 into a new token 450
# merging (330, 267) with freq 142 into a new token 451
# merging (182, 291) with freq 142 into a new token 452
# merging (306, 364) with freq 141 into a new token 453
# merging (264, 130) with freq 140 into a new token 454
# merging (290, 326) with freq 140 into a new token 455
# merging (273, 298) with freq 138 into a new token 456
# merging (304, 136) with freq 138 into a new token 457
# merging (268, 174) with freq 137 into a new token 458
# merging (264, 178) with freq 137 into a new token 459
# merging (156, 267) with freq 136 into a new token 460
# merging (325, 294) with freq 134 into a new token 461
# merging (299, 275) with freq 133 into a new token 462
# merging (272, 282) with freq 133 into a new token 463
# merging (288, 267) with freq 133 into a new token 464
# merging (262, 284) with freq 132 into a new token 465
# merging (154, 292) with freq 132 into a new token 466
# merging (149, 266) with freq 132 into a new token 467
# merging (298, 267) with freq 131 into a new token 468
# merging (261, 165) with freq 131 into a new token 469
# merging (270, 49) with freq 130 into a new token 470
# merging (259, 342) with freq 130 into a new token 471
# merging (403, 381) with freq 130 into a new token 472
# merging (257, 143) with freq 130 into a new token 473
# merging (299, 277) with freq 129 into a new token 474
# merging (276, 150) with freq 129 into a new token 475
# merging (290, 329) with freq 128 into a new token 476
# merging (271, 282) with freq 127 into a new token 477
# merging (280, 363) with freq 127 into a new token 478
# merging (271, 281) with freq 126 into a new token 479
# merging (302, 282) with freq 125 into a new token 480
# merging (257, 155) with freq 124 into a new token 481
# merging (265, 318) with freq 124 into a new token 482
# merging (262, 266) with freq 123 into a new token 483
# merging (262, 278) with freq 123 into a new token 484
# merging (290, 309) with freq 123 into a new token 485
# merging (264, 156) with freq 120 into a new token 486
# merging (256, 136) with freq 119 into a new token 487
# merging (270, 50) with freq 118 into a new token 488
# merging (276, 149) with freq 118 into a new token 489
# merging (258, 166) with freq 117 into a new token 490
# merging (266, 332) with freq 116 into a new token 491
# merging (369, 156) with freq 115 into a new token 492
# merging (268, 156) with freq 115 into a new token 493
# merging (262, 265) with freq 113 into a new token 494
# merging (162, 381) with freq 113 into a new token 495
# merging (288, 274) with freq 112 into a new token 496
# merging (290, 315) with freq 112 into a new token 497
# merging (130, 294) with freq 110 into a new token 498
# merging (292, 326) with freq 110 into a new token 499
# merging (292, 329) with freq 109 into a new token 500
# merging (178, 414) with freq 109 into a new token 501
# merging (382, 283) with freq 108 into a new token 502
# merging (304, 154) with freq 108 into a new token 503
# merging (271, 342) with freq 108 into a new token 504
# merging (275, 156) with freq 108 into a new token 505
# merging (303, 184) with freq 107 into a new token 506
# merging (302, 319) with freq 107 into a new token 507
# merging (272, 287) with freq 107 into a new token 508
# merging (284, 346) with freq 107 into a new token 509
# merging (276, 166) with freq 106 into a new token 510
# merging (374, 259) with freq 106 into a new token 511
# merging (262, 280) with freq 105 into a new token 512
# merging (316, 183) with freq 105 into a new token 513
# merging (337, 279) with freq 105 into a new token 514
# merging (357, 279) with freq 104 into a new token 515
# merging (305, 433) with freq 104 into a new token 516
# merging (259, 344) with freq 103 into a new token 517
# merging (262, 286) with freq 102 into a new token 518
# merging (262, 289) with freq 102 into a new token 519
# merging (278, 282) with freq 101 into a new token 520
# merging (341, 267) with freq 101 into a new token 521
# merging (272, 307) with freq 101 into a new token 522
# merging (273, 287) with freq 101 into a new token 523
# merging (133, 282) with freq 100 into a new token 524
# merging (154, 283) with freq 99 into a new token 525
# merging (308, 173) with freq 97 into a new token 526
# merging (312, 401) with freq 97 into a new token 527
# merging (276, 184) with freq 97 into a new token 528
# merging (271, 267) with freq 96 into a new token 529
# merging (293, 314) with freq 96 into a new token 530
# merging (303, 168) with freq 94 into a new token 531
# merging (271, 344) with freq 94 into a new token 532
# merging (264, 133) with freq 94 into a new token 533
# merging (277, 156) with freq 93 into a new token 534
# merging (276, 164) with freq 93 into a new token 535
# merging (268, 151) with freq 92 into a new token 536
# merging (286, 318) with freq 92 into a new token 537
# merging (261, 167) with freq 91 into a new token 538
# merging (336, 400) with freq 91 into a new token 539
# merging (263, 289) with freq 90 into a new token 540
# merging (288, 296) with freq 89 into a new token 541
# merging (265, 267) with freq 89 into a new token 542
# merging (308, 498) with freq 89 into a new token 543
# merging (280, 272) with freq 88 into a new token 544
# merging (276, 170) with freq 88 into a new token 545
# merging (322, 300) with freq 87 into a new token 546
# merging (293, 267) with freq 87 into a new token 547
# merging (276, 154) with freq 87 into a new token 548
# merging (281, 320) with freq 87 into a new token 549
# merging (308, 174) with freq 86 into a new token 550
# merging (268, 173) with freq 86 into a new token 551
# merging (268, 170) with freq 86 into a new token 552
# merging (277, 149) with freq 85 into a new token 553
# merging (276, 172) with freq 85 into a new token 554
# merging (268, 133) with freq 85 into a new token 555
# merging (278, 409) with freq 85 into a new token 556
# merging (259, 384) with freq 85 into a new token 557
# merging (280, 283) with freq 84 into a new token 558
# merging (259, 265) with freq 84 into a new token 559
# merging (334, 167) with freq 84 into a new token 560
# merging (279, 285) with freq 84 into a new token 561
# merging (268, 164) with freq 84 into a new token 562
# merging (277, 172) with freq 83 into a new token 563
# merging (289, 307) with freq 82 into a new token 564
# merging (170, 346) with freq 82 into a new token 565
# merging (293, 366) with freq 82 into a new token 566
# merging (543, 263) with freq 82 into a new token 567
# merging (270, 51) with freq 81 into a new token 568
# merging (275, 172) with freq 81 into a new token 569
# merging (281, 271) with freq 81 into a new token 570
# merging (320, 295) with freq 81 into a new token 571
# merging (315, 371) with freq 81 into a new token 572
# merging (284, 266) with freq 80 into a new token 573
# merging (256, 495) with freq 80 into a new token 574
# merging (278, 451) with freq 80 into a new token 575
# merging (278, 292) with freq 79 into a new token 576
# merging (268, 166) with freq 79 into a new token 577
# merging (272, 294) with freq 79 into a new token 578
# merging (302, 298) with freq 79 into a new token 579
# merging (473, 285) with freq 78 into a new token 580
# merging (263, 262) with freq 78 into a new token 581
# merging (261, 137) with freq 78 into a new token 582
# merging (288, 376) with freq 78 into a new token 583
# merging (461, 530) with freq 78 into a new token 584
# merging (275, 371) with freq 77 into a new token 585
# merging (306, 363) with freq 77 into a new token 586
# merging (291, 266) with freq 76 into a new token 587
# merging (301, 269) with freq 76 into a new token 588
# merging (268, 334) with freq 76 into a new token 589
# merging (279, 343) with freq 76 into a new token 590
# merging (279, 323) with freq 75 into a new token 591
# merging (289, 389) with freq 75 into a new token 592
# merging (278, 267) with freq 74 into a new token 593
# merging (265, 266) with freq 74 into a new token 594
# merging (257, 171) with freq 74 into a new token 595
# merging (372, 263) with freq 74 into a new token 596
# merging (317, 168) with freq 74 into a new token 597
# merging (277, 174) with freq 73 into a new token 598
# merging (286, 294) with freq 73 into a new token 599
# merging (272, 285) with freq 73 into a new token 600
# merging (299, 283) with freq 73 into a new token 601
# merging (304, 183) with freq 72 into a new token 602
# merging (284, 300) with freq 72 into a new token 603
# merging (261, 154) with freq 71 into a new token 604
# merging (265, 274) with freq 71 into a new token 605
# merging (265, 483) with freq 71 into a new token 606
# merging (261, 269) with freq 71 into a new token 607
# merging (272, 347) with freq 71 into a new token 608
# merging (316, 269) with freq 71 into a new token 609
# merging (264, 172) with freq 70 into a new token 610
# merging (276, 156) with freq 70 into a new token 611
# merging (264, 166) with freq 70 into a new token 612
# merging (257, 150) with freq 70 into a new token 613
# merging (264, 183) with freq 70 into a new token 614
# merging (261, 138) with freq 70 into a new token 615
# merging (280, 387) with freq 70 into a new token 616
# merging (303, 418) with freq 70 into a new token 617
# merging (280, 389) with freq 69 into a new token 618
# merging (289, 313) with freq 69 into a new token 619
# merging (350, 400) with freq 69 into a new token 620
# merging (272, 263) with freq 69 into a new token 621
# merging (271, 283) with freq 68 into a new token 622
# merging (503, 267) with freq 68 into a new token 623
# merging (292, 309) with freq 68 into a new token 624
# merging (133, 267) with freq 68 into a new token 625
# merging (275, 149) with freq 67 into a new token 626
# merging (273, 281) with freq 67 into a new token 627
# merging (303, 466) with freq 67 into a new token 628
# merging (278, 333) with freq 67 into a new token 629
# merging (292, 294) with freq 67 into a new token 630
# merging (274, 296) with freq 67 into a new token 631
# merging (271, 319) with freq 67 into a new token 632
# merging (348, 283) with freq 67 into a new token 633
# merging (275, 164) with freq 66 into a new token 634
# merging (320, 287) with freq 66 into a new token 635
# merging (276, 157) with freq 66 into a new token 636
# merging (261, 149) with freq 66 into a new token 637
# merging (265, 285) with freq 66 into a new token 638
# merging (304, 173) with freq 66 into a new token 639
# merging (341, 307) with freq 65 into a new token 640
# merging (280, 340) with freq 65 into a new token 641
# merging (271, 321) with freq 65 into a new token 642
# merging (185, 450) with freq 65 into a new token 643
# merging (303, 501) with freq 65 into a new token 644
# merging (377, 263) with freq 64 into a new token 645
# merging (299, 263) with freq 64 into a new token 646
# merging (257, 452) with freq 64 into a new token 647
# merging (279, 281) with freq 64 into a new token 648
# merging (278, 266) with freq 64 into a new token 649
# merging (587, 523) with freq 63 into a new token 650
# merging (282, 263) with freq 63 into a new token 651
# merging (305, 295) with freq 63 into a new token 652
# merging (302, 297) with freq 62 into a new token 653
# merging (296, 267) with freq 62 into a new token 654
# merging (268, 176) with freq 61 into a new token 655
# merging (303, 172) with freq 61 into a new token 656
# merging (168, 486) with freq 61 into a new token 657
# merging (324, 450) with freq 61 into a new token 658
# merging (330, 273) with freq 61 into a new token 659
# merging (345, 290) with freq 61 into a new token 660
# merging (260, 308) with freq 60 into a new token 661
# merging (264, 143) with freq 60 into a new token 662
# merging (299, 323) with freq 60 into a new token 663
# merging (275, 174) with freq 59 into a new token 664
# merging (279, 282) with freq 59 into a new token 665
# merging (271, 293) with freq 59 into a new token 666
# merging (257, 152) with freq 59 into a new token 667
# merging (280, 337) with freq 59 into a new token 668
# merging (278, 356) with freq 59 into a new token 669
# merging (156, 290) with freq 58 into a new token 670
# merging (377, 297) with freq 58 into a new token 671
# merging (278, 379) with freq 58 into a new token 672
# merging (282, 262) with freq 58 into a new token 673
# merging (285, 263) with freq 58 into a new token 674
# merging (276, 151) with freq 57 into a new token 675
# merging (336, 282) with freq 57 into a new token 676
# merging (510, 351) with freq 57 into a new token 677
# merging (303, 167) with freq 57 into a new token 678
# merging (264, 170) with freq 57 into a new token 679
# merging (264, 167) with freq 56 into a new token 680
# merging (334, 418) with freq 56 into a new token 681
# merging (185, 263) with freq 56 into a new token 682
# merging (296, 300) with freq 56 into a new token 683
# merging (275, 154) with freq 56 into a new token 684
# merging (175, 266) with freq 56 into a new token 685
# merging (310, 391) with freq 56 into a new token 686
# merging (322, 333) with freq 55 into a new token 687
# merging (133, 319) with freq 55 into a new token 688
# merging (292, 315) with freq 55 into a new token 689
# merging (309, 149) with freq 55 into a new token 690
# merging (338, 355) with freq 55 into a new token 691
# merging (309, 164) with freq 55 into a new token 692
# merging (268, 178) with freq 55 into a new token 693
# merging (133, 298) with freq 55 into a new token 694
# merging (310, 296) with freq 55 into a new token 695
# merging (369, 184) with freq 55 into a new token 696
# merging (324, 287) with freq 55 into a new token 697
# merging (310, 298) with freq 54 into a new token 698
# merging (258, 164) with freq 54 into a new token 699
# merging (284, 396) with freq 54 into a new token 700
# merging (280, 276) with freq 54 into a new token 701
# merging (261, 150) with freq 54 into a new token 702
# merging (274, 317) with freq 54 into a new token 703
# merging (277, 164) with freq 54 into a new token 704
# merging (265, 333) with freq 54 into a new token 705
# merging (265, 437) with freq 54 into a new token 706
# merging (288, 352) with freq 54 into a new token 707
# merging (348, 263) with freq 53 into a new token 708
# merging (296, 367) with freq 53 into a new token 709
# merging (449, 263) with freq 53 into a new token 710
# merging (284, 430) with freq 53 into a new token 711
# merging (305, 362) with freq 53 into a new token 712
# merging (324, 415) with freq 52 into a new token 713
# merging (310, 380) with freq 52 into a new token 714
# merging (266, 380) with freq 52 into a new token 715
# merging (659, 387) with freq 52 into a new token 716
# merging (281, 259) with freq 52 into a new token 717
# merging (280, 274) with freq 52 into a new token 718
# merging (337, 397) with freq 52 into a new token 719
# merging (273, 343) with freq 51 into a new token 720
# merging (408, 314) with freq 51 into a new token 721
# merging (334, 168) with freq 51 into a new token 722
# merging (265, 346) with freq 51 into a new token 723
# merging (271, 297) with freq 51 into a new token 724
# merging (284, 514) with freq 51 into a new token 725
# merging (446, 287) with freq 51 into a new token 726
# merging (297, 267) with freq 51 into a new token 727
# merging (266, 320) with freq 51 into a new token 728
# merging (279, 403) with freq 51 into a new token 729
# merging (305, 434) with freq 51 into a new token 730
# merging (294, 267) with freq 50 into a new token 731
# merging (287, 259) with freq 50 into a new token 732
# merging (323, 267) with freq 50 into a new token 733
# merging (321, 172) with freq 50 into a new token 734
# merging (279, 330) with freq 50 into a new token 735
# merging (299, 378) with freq 50 into a new token 736
# merging (525, 272) with freq 50 into a new token 737
# merging (170, 275) with freq 50 into a new token 738
# merging (383, 291) with freq 49 into a new token 739
# merging (304, 138) with freq 49 into a new token 740
# merging (365, 362) with freq 49 into a new token 741
# merging (338, 356) with freq 49 into a new token 742
# merging (304, 159) with freq 49 into a new token 743
# merging (264, 328) with freq 48 into a new token 744
# merging (330, 263) with freq 48 into a new token 745
# merging (302, 295) with freq 48 into a new token 746
# merging (315, 156) with freq 48 into a new token 747
# merging (324, 584) with freq 48 into a new token 748
# merging (256, 138) with freq 48 into a new token 749
# merging (312, 266) with freq 48 into a new token 750
# merging (306, 447) with freq 48 into a new token 751
# merging (309, 172) with freq 47 into a new token 752
# merging (288, 283) with freq 47 into a new token 753
# merging (287, 283) with freq 47 into a new token 754
# merging (286, 346) with freq 47 into a new token 755
# merging (357, 490) with freq 47 into a new token 756
# merging (361, 490) with freq 47 into a new token 757
# merging (287, 293) with freq 46 into a new token 758
# merging (167, 263) with freq 46 into a new token 759
# merging (315, 164) with freq 46 into a new token 760
# merging (321, 149) with freq 46 into a new token 761
# merging (550, 333) with freq 45 into a new token 762
# merging (322, 318) with freq 45 into a new token 763
# merging (284, 502) with freq 45 into a new token 764
# merging (276, 269) with freq 45 into a new token 765
# merging (280, 511) with freq 45 into a new token 766
# merging (271, 298) with freq 45 into a new token 767
# merging (405, 275) with freq 45 into a new token 768
# merging (336, 508) with freq 45 into a new token 769
# merging (312, 358) with freq 45 into a new token 770
# merging (137, 263) with freq 45 into a new token 771
# merging (684, 756) with freq 45 into a new token 772
# merging (257, 135) with freq 44 into a new token 773
# merging (318, 355) with freq 44 into a new token 774
# merging (348, 379) with freq 44 into a new token 775
# merging (278, 578) with freq 44 into a new token 776
# merging (616, 262) with freq 44 into a new token 777
# merging (303, 166) with freq 44 into a new token 778
# merging (349, 262) with freq 44 into a new token 779
# merging (309, 156) with freq 44 into a new token 780
# merging (278, 358) with freq 44 into a new token 781
# merging (168, 313) with freq 43 into a new token 782
# merging (276, 167) with freq 43 into a new token 783
# merging (319, 174) with freq 43 into a new token 784
# merging (319, 172) with freq 43 into a new token 785
# merging (315, 172) with freq 43 into a new token 786
# merging (280, 331) with freq 43 into a new token 787
# merging (264, 150) with freq 43 into a new token 788
# merging (736, 267) with freq 43 into a new token 789
# merging (260, 277) with freq 43 into a new token 790
# merging (268, 350) with freq 43 into a new token 791
# merging (133, 295) with freq 43 into a new token 792
# merging (279, 295) with freq 43 into a new token 793
# merging (409, 272) with freq 43 into a new token 794
# merging (185, 415) with freq 42 into a new token 795
# merging (302, 263) with freq 42 into a new token 796
# merging (308, 149) with freq 42 into a new token 797
# merging (368, 298) with freq 42 into a new token 798
# merging (325, 296) with freq 42 into a new token 799
# merging (373, 358) with freq 42 into a new token 800
# merging (315, 149) with freq 42 into a new token 801
# merging (289, 263) with freq 42 into a new token 802
# merging (276, 183) with freq 42 into a new token 803
# merging (297, 263) with freq 42 into a new token 804
# merging (303, 350) with freq 42 into a new token 805
# merging (278, 472) with freq 42 into a new token 806
# merging (274, 294) with freq 41 into a new token 807
# merging (143, 317) with freq 41 into a new token 808
# merging (265, 281) with freq 41 into a new token 809
# merging (143, 285) with freq 41 into a new token 810
# merging (343, 432) with freq 41 into a new token 811
# merging (395, 287) with freq 41 into a new token 812
# merging (312, 391) with freq 41 into a new token 813
# merging (292, 271) with freq 41 into a new token 814
# merging (392, 285) with freq 41 into a new token 815
# merging (324, 263) with freq 40 into a new token 816
# merging (170, 318) with freq 40 into a new token 817
# merging (294, 297) with freq 40 into a new token 818
# merging (185, 340) with freq 40 into a new token 819
# merging (271, 285) with freq 40 into a new token 820
# merging (368, 267) with freq 40 into a new token 821
# merging (317, 156) with freq 40 into a new token 822
# merging (442, 262) with freq 40 into a new token 823
# merging (173, 425) with freq 40 into a new token 824
# merging (288, 293) with freq 40 into a new token 825
# merging (173, 391) with freq 40 into a new token 826
# merging (294, 259) with freq 39 into a new token 827
# merging (305, 267) with freq 39 into a new token 828
# merging (325, 378) with freq 39 into a new token 829
# merging (324, 274) with freq 39 into a new token 830
# merging (155, 279) with freq 39 into a new token 831
# merging (309, 174) with freq 39 into a new token 832
# merging (324, 457) with freq 39 into a new token 833
# merging (321, 174) with freq 39 into a new token 834
# merging (324, 340) with freq 39 into a new token 835
# merging (460, 285) with freq 39 into a new token 836
# merging (278, 347) with freq 39 into a new token 837
# merging (334, 184) with freq 39 into a new token 838
# merging (168, 389) with freq 39 into a new token 839
# merging (173, 296) with freq 39 into a new token 840
# merging (303, 185) with freq 39 into a new token 841
# merging (331, 454) with freq 39 into a new token 842
# merging (327, 279) with freq 39 into a new token 843
# merging (373, 609) with freq 39 into a new token 844
# merging (322, 267) with freq 38 into a new token 845
# merging (420, 285) with freq 38 into a new token 846
# merging (303, 174) with freq 38 into a new token 847
# merging (288, 426) with freq 38 into a new token 848
# merging (166, 429) with freq 38 into a new token 849
# merging (481, 295) with freq 38 into a new token 850
# merging (331, 262) with freq 38 into a new token 851
# merging (278, 345) with freq 38 into a new token 852
# merging (293, 749) with freq 38 into a new token 853
# merging (265, 415) with freq 37 into a new token 854
# merging (319, 149) with freq 37 into a new token 855
# merging (272, 267) with freq 37 into a new token 856
# merging (324, 351) with freq 37 into a new token 857
# merging (134, 263) with freq 37 into a new token 858
# merging (405, 277) with freq 37 into a new token 859
# merging (170, 294) with freq 37 into a new token 860
# merging (350, 508) with freq 37 into a new token 861
# merging (308, 269) with freq 37 into a new token 862
# merging (176, 266) with freq 37 into a new token 863
# merging (292, 423) with freq 37 into a new token 864
# merging (738, 757) with freq 37 into a new token 865
# merging (276, 130) with freq 36 into a new token 866
# merging (268, 185) with freq 36 into a new token 867
# merging (281, 417) with freq 36 into a new token 868
# merging (315, 174) with freq 36 into a new token 869
# merging (278, 650) with freq 36 into a new token 870
# merging (337, 282) with freq 36 into a new token 871
# merging (284, 365) with freq 36 into a new token 872
# merging (372, 340) with freq 36 into a new token 873
# merging (396, 263) with freq 36 into a new token 874
# merging (173, 380) with freq 36 into a new token 875
# merging (310, 291) with freq 36 into a new token 876
# merging (325, 266) with freq 36 into a new token 877
# merging (287, 267) with freq 35 into a new token 878
# merging (348, 292) with freq 35 into a new token 879
# merging (392, 282) with freq 35 into a new token 880
# merging (357, 263) with freq 35 into a new token 881
# merging (496, 296) with freq 35 into a new token 882
# merging (375, 390) with freq 35 into a new token 883
# merging (149, 283) with freq 35 into a new token 884
# merging (290, 271) with freq 35 into a new token 885
# merging (292, 427) with freq 35 into a new token 886
# merging (310, 425) with freq 35 into a new token 887
# merging (263, 273) with freq 34 into a new token 888
# merging (388, 263) with freq 34 into a new token 889
# merging (353, 307) with freq 34 into a new token 890
# merging (308, 410) with freq 34 into a new token 891
# merging (284, 301) with freq 34 into a new token 892
# merging (338, 296) with freq 34 into a new token 893
# merging (286, 300) with freq 34 into a new token 894
# merging (288, 295) with freq 34 into a new token 895
# merging (284, 459) with freq 34 into a new token 896
# merging (359, 285) with freq 34 into a new token 897
# merging (359, 309) with freq 34 into a new token 898
# merging (297, 367) with freq 34 into a new token 899
# merging (288, 272) with freq 34 into a new token 900
# merging (404, 371) with freq 34 into a new token 901
# merging (278, 283) with freq 34 into a new token 902
# merging (273, 267) with freq 34 into a new token 903
# merging (265, 588) with freq 34 into a new token 904
# merging (526, 296) with freq 34 into a new token 905
# merging (304, 156) with freq 34 into a new token 906
# merging (297, 262) with freq 34 into a new token 907
# merging (428, 400) with freq 34 into a new token 908
# merging (296, 345) with freq 34 into a new token 909
# merging (341, 309) with freq 34 into a new token 910
# merging (305, 426) with freq 34 into a new token 911
# merging (368, 425) with freq 34 into a new token 912
# merging (454, 343) with freq 33 into a new token 913
# merging (306, 475) with freq 33 into a new token 914
# merging (302, 287) with freq 33 into a new token 915
# merging (288, 282) with freq 33 into a new token 916
# merging (151, 333) with freq 33 into a new token 917
# merging (151, 318) with freq 33 into a new token 918
# merging (405, 314) with freq 33 into a new token 919
# merging (301, 328) with freq 33 into a new token 920
# merging (357, 282) with freq 33 into a new token 921
# merging (176, 358) with freq 33 into a new token 922
# merging (282, 267) with freq 33 into a new token 923
# merging (384, 169) with freq 33 into a new token 924
# merging (289, 547) with freq 32 into a new token 925
# merging (288, 434) with freq 32 into a new token 926
# merging (357, 281) with freq 32 into a new token 927
# merging (321, 156) with freq 32 into a new token 928
# merging (329, 156) with freq 32 into a new token 929
# merging (265, 382) with freq 32 into a new token 930
# merging (316, 135) with freq 32 into a new token 931
# merging (336, 335) with freq 32 into a new token 932
# merging (257, 165) with freq 32 into a new token 933
# merging (362, 277) with freq 32 into a new token 934
# merging (372, 267) with freq 32 into a new token 935
# merging (133, 314) with freq 32 into a new token 936
# merging (176, 401) with freq 32 into a new token 937
# merging (429, 285) with freq 32 into a new token 938
# merging (289, 469) with freq 32 into a new token 939
# merging (280, 317) with freq 32 into a new token 940
# merging (345, 313) with freq 31 into a new token 941
# merging (303, 178) with freq 31 into a new token 942
# merging (383, 259) with freq 31 into a new token 943
# merging (329, 371) with freq 31 into a new token 944
# merging (336, 408) with freq 31 into a new token 945
# merging (280, 447) with freq 31 into a new token 946
# merging (327, 344) with freq 31 into a new token 947
# merging (303, 183) with freq 31 into a new token 948
# merging (137, 297) with freq 31 into a new token 949
# merging (332, 277) with freq 31 into a new token 950
# merging (406, 289) with freq 31 into a new token 951
# merging (287, 290) with freq 31 into a new token 952
# merging (154, 263) with freq 31 into a new token 953
# merging (289, 430) with freq 31 into a new token 954
# merging (261, 159) with freq 31 into a new token 955
# merging (265, 456) with freq 31 into a new token 956
# merging (351, 168) with freq 31 into a new token 957
# merging (296, 263) with freq 31 into a new token 958
# merging (257, 161) with freq 31 into a new token 959
# merging (295, 282) with freq 31 into a new token 960
# merging (464, 285) with freq 31 into a new token 961
# merging (299, 342) with freq 30 into a new token 962
# merging (310, 468) with freq 30 into a new token 963
# merging (473, 317) with freq 30 into a new token 964
# merging (319, 173) with freq 30 into a new token 965
# merging (595, 283) with freq 30 into a new token 966
# merging (336, 709) with freq 30 into a new token 967
# merging (284, 475) with freq 30 into a new token 968
# merging (332, 275) with freq 30 into a new token 969
# merging (283, 414) with freq 30 into a new token 970
# merging (306, 429) with freq 30 into a new token 971
# merging (370, 309) with freq 30 into a new token 972
# merging (280, 754) with freq 30 into a new token 973
# merging (261, 495) with freq 30 into a new token 974
# merging (639, 259) with freq 30 into a new token 975
# merging (302, 811) with freq 30 into a new token 976
# merging (170, 300) with freq 30 into a new token 977
# merging (590, 262) with freq 30 into a new token 978
# merging (651, 374) with freq 30 into a new token 979
# merging (305, 291) with freq 30 into a new token 980
# merging (171, 333) with freq 30 into a new token 981
# merging (322, 877) with freq 30 into a new token 982
# merging (265, 356) with freq 30 into a new token 983
# merging (264, 418) with freq 29 into a new token 984
# merging (353, 267) with freq 29 into a new token 985
# merging (273, 367) with freq 29 into a new token 986
# merging (527, 545) with freq 29 into a new token 987
# merging (336, 868) with freq 29 into a new token 988
# merging (310, 263) with freq 29 into a new token 989
# merging (274, 282) with freq 29 into a new token 990
# merging (286, 341) with freq 29 into a new token 991
# merging (305, 323) with freq 29 into a new token 992
# merging (594, 323) with freq 29 into a new token 993
# merging (302, 285) with freq 29 into a new token 994
# merging (274, 340) with freq 29 into a new token 995
# merging (431, 294) with freq 29 into a new token 996
# merging (319, 168) with freq 29 into a new token 997
# merging (280, 313) with freq 29 into a new token 998
# merging (154, 379) with freq 29 into a new token 999
# merging (421, 307) with freq 29 into a new token 1000
# merging (436, 402) with freq 29 into a new token 1001
# merging (372, 352) with freq 29 into a new token 1002
# merging (265, 314) with freq 29 into a new token 1003
# merging (262, 288) with freq 29 into a new token 1004
# merging (428, 674) with freq 29 into a new token 1005
# merging (164, 433) with freq 29 into a new token 1006
# merging (303, 173) with freq 28 into a new token 1007
# merging (612, 720) with freq 28 into a new token 1008
# merging (268, 416) with freq 28 into a new token 1009
# merging (278, 394) with freq 28 into a new token 1010
# merging (265, 457) with freq 28 into a new token 1011
# merging (268, 410) with freq 28 into a new token 1012
# merging (321, 168) with freq 28 into a new token 1013
# merging (289, 333) with freq 28 into a new token 1014
# merging (309, 168) with freq 28 into a new token 1015
# merging (302, 335) with freq 28 into a new token 1016
# merging (268, 134) with freq 28 into a new token 1017
# merging (178, 355) with freq 28 into a new token 1018
# merging (284, 343) with freq 28 into a new token 1019
# merging (422, 600) with freq 28 into a new token 1020
# merging (290, 423) with freq 28 into a new token 1021
# merging (428, 282) with freq 28 into a new token 1022
# merging (292, 267) with freq 28 into a new token 1023
# merging (527, 554) with freq 28 into a new token 1024
# merging (348, 417) with freq 28 into a new token 1025
# merging (185, 584) with freq 28 into a new token 1026
# merging (304, 167) with freq 28 into a new token 1027
# merging (295, 283) with freq 28 into a new token 1028
# merging (170, 663) with freq 28 into a new token 1029
# merging (310, 340) with freq 28 into a new token 1030
# merging (368, 293) with freq 28 into a new token 1031
# merging (326, 149) with freq 27 into a new token 1032
# merging (310, 355) with freq 27 into a new token 1033
# merging (284, 461) with freq 27 into a new token 1034
# merging (319, 156) with freq 27 into a new token 1035
# merging (323, 273) with freq 27 into a new token 1036
# merging (284, 263) with freq 27 into a new token 1037
# merging (281, 267) with freq 27 into a new token 1038
# merging (266, 318) with freq 27 into a new token 1039
# merging (306, 435) with freq 27 into a new token 1040
# merging (271, 330) with freq 27 into a new token 1041
# merging (290, 427) with freq 27 into a new token 1042
# merging (289, 540) with freq 27 into a new token 1043
# merging (305, 352) with freq 27 into a new token 1044
# merging (284, 703) with freq 27 into a new token 1045
# merging (310, 566) with freq 27 into a new token 1046
# merging (173, 566) with freq 27 into a new token 1047
# merging (506, 513) with freq 27 into a new token 1048
# merging (323, 262) with freq 27 into a new token 1049
# merging (299, 314) with freq 27 into a new token 1050
# merging (438, 347) with freq 27 into a new token 1051
# merging (384, 168) with freq 27 into a new token 1052
# merging (334, 350) with freq 27 into a new token 1053
# merging (377, 397) with freq 27 into a new token 1054
# merging (275, 168) with freq 26 into a new token 1055
# merging (306, 399) with freq 26 into a new token 1056
# merging (279, 400) with freq 26 into a new token 1057
# merging (297, 291) with freq 26 into a new token 1058
# merging (264, 159) with freq 26 into a new token 1059
# merging (306, 602) with freq 26 into a new token 1060
# merging (708, 351) with freq 26 into a new token 1061
# merging (831, 48) with freq 26 into a new token 1062
# merging (290, 532) with freq 26 into a new token 1063
# merging (306, 354) with freq 26 into a new token 1064
# merging (395, 282) with freq 26 into a new token 1065
# merging (272, 342) with freq 26 into a new token 1066
# merging (327, 342) with freq 26 into a new token 1067
# merging (261, 183) with freq 26 into a new token 1068
# merging (276, 181) with freq 26 into a new token 1069
# merging (265, 396) with freq 26 into a new token 1070
# merging (321, 170) with freq 26 into a new token 1071
# merging (288, 675) with freq 26 into a new token 1072
# merging (281, 263) with freq 26 into a new token 1073
# merging (338, 414) with freq 26 into a new token 1074
# merging (257, 685) with freq 26 into a new token 1075
# merging (308, 164) with freq 26 into a new token 1076
# merging (284, 290) with freq 26 into a new token 1077
# merging (280, 359) with freq 26 into a new token 1078
# merging (384, 167) with freq 26 into a new token 1079
# merging (516, 292) with freq 26 into a new token 1080
# merging (174, 502) with freq 25 into a new token 1081
# merging (289, 292) with freq 25 into a new token 1082
# merging (308, 156) with freq 25 into a new token 1083
# merging (284, 677) with freq 25 into a new token 1084
# merging (266, 307) with freq 25 into a new token 1085
# merging (546, 322) with freq 25 into a new token 1086
# merging (284, 352) with freq 25 into a new token 1087
# merging (338, 631) with freq 25 into a new token 1088
# merging (317, 149) with freq 25 into a new token 1089
# merging (345, 259) with freq 25 into a new token 1090
# merging (172, 263) with freq 25 into a new token 1091
# merging (278, 513) with freq 25 into a new token 1092
# merging (265, 293) with freq 25 into a new token 1093
# merging (467, 347) with freq 25 into a new token 1094
# merging (312, 702) with freq 25 into a new token 1095
# merging (290, 394) with freq 25 into a new token 1096
# merging (275, 416) with freq 25 into a new token 1097
# merging (542, 399) with freq 25 into a new token 1098
# merging (385, 874) with freq 25 into a new token 1099
# merging (306, 276) with freq 25 into a new token 1100
# merging (452, 313) with freq 25 into a new token 1101
# merging (173, 263) with freq 25 into a new token 1102
# merging (377, 387) with freq 25 into a new token 1103
# merging (265, 358) with freq 25 into a new token 1104
# merging (278, 719) with freq 25 into a new token 1105
# merging (164, 295) with freq 25 into a new token 1106
# merging (557, 167) with freq 25 into a new token 1107
# merging (384, 865) with freq 25 into a new token 1108
# merging (271, 280) with freq 24 into a new token 1109
# merging (151, 300) with freq 24 into a new token 1110
# merging (310, 283) with freq 24 into a new token 1111
# merging (288, 767) with freq 24 into a new token 1112
# merging (321, 185) with freq 24 into a new token 1113
# merging (420, 259) with freq 24 into a new token 1114
# merging (331, 462) with freq 24 into a new token 1115
# merging (326, 156) with freq 24 into a new token 1116
# merging (161, 381) with freq 24 into a new token 1117
# merging (370, 315) with freq 24 into a new token 1118
# merging (838, 456) with freq 24 into a new token 1119
# merging (266, 323) with freq 24 into a new token 1120
# merging (299, 574) with freq 24 into a new token 1121
# merging (321, 334) with freq 24 into a new token 1122
# merging (299, 367) with freq 24 into a new token 1123
# merging (302, 296) with freq 24 into a new token 1124
# merging (267, 285) with freq 24 into a new token 1125
# merging (341, 315) with freq 24 into a new token 1126
# merging (272, 283) with freq 24 into a new token 1127
# merging (383, 298) with freq 24 into a new token 1128
# merging (633, 272) with freq 24 into a new token 1129
# merging (305, 365) with freq 24 into a new token 1130
# merging (355, 263) with freq 23 into a new token 1131
# merging (422, 774) with freq 23 into a new token 1132
# merging (927, 489) with freq 23 into a new token 1133
# merging (310, 299) with freq 23 into a new token 1134
# merging (154, 739) with freq 23 into a new token 1135
# merging (336, 285) with freq 23 into a new token 1136
# merging (280, 295) with freq 23 into a new token 1137
# merging (277, 168) with freq 23 into a new token 1138
# merging (263, 282) with freq 23 into a new token 1139
# merging (265, 710) with freq 23 into a new token 1140
# merging (278, 455) with freq 23 into a new token 1141
# merging (340, 149) with freq 23 into a new token 1142
# merging (308, 167) with freq 23 into a new token 1143
# merging (281, 407) with freq 23 into a new token 1144
# merging (373, 636) with freq 23 into a new token 1145
# merging (531, 293) with freq 23 into a new token 1146
# merging (618, 359) with freq 23 into a new token 1147
# merging (305, 419) with freq 23 into a new token 1148
# merging (344, 274) with freq 23 into a new token 1149
# merging (271, 265) with freq 23 into a new token 1150
# merging (310, 293) with freq 23 into a new token 1151
# ...
# merging (697, 886) with freq 4 into a new token 4202
# merging (322, 2627) with freq 4 into a new token 4203
# merging (268, 999) with freq 4 into a new token 4204
# merging (1224, 292) with freq 4 into a new token 4205
# merging (1182, 343) with freq 4 into a new token 4206
# merging (696, 497) with freq 4 into a new token 4207
# merging (1793, 1028) with freq 4 into a new token 4208
# merging (1681, 2315) with freq 4 into a new token 4209
# merging (810, 580) with freq 4 into a new token 4210
# merging (185, 293) with freq 4 into a new token 4211
# merging (551, 391) with freq 4 into a new token 4212
# merging (597, 389) with freq 4 into a new token 4213
# merging (168, 296) with freq 4 into a new token 4214
# merging (304, 269) with freq 4 into a new token 4215
# merging (295, 345) with freq 4 into a new token 4216
# merging (1234, 522) with freq 4 into a new token 4217
# merging (155, 1281) with freq 4 into a new token 4218
# merging (995, 172) with freq 4 into a new token 4219
# merging (562, 298) with freq 4 into a new token 4220
# merging (274, 597) with freq 4 into a new token 4221
# merging (688, 1199) with freq 4 into a new token 4222
# merging (289, 349) with freq 4 into a new token 4223
# merging (1328, 455) with freq 4 into a new token 4224
# merging (446, 2218) with freq 4 into a new token 4225
# merging (734, 409) with freq 4 into a new token 4226
# merging (341, 515) with freq 4 into a new token 4227
# merging (1011, 277) with freq 4 into a new token 4228
# merging (278, 1684) with freq 4 into a new token 4229
# merging (446, 424) with freq 4 into a new token 4230
# merging (593, 398) with freq 4 into a new token 4231
# merging (556, 859) with freq 4 into a new token 4232
# merging (320, 710) with freq 4 into a new token 4233
# merging (1375, 397) with freq 4 into a new token 4234
# merging (686, 965) with freq 4 into a new token 4235
# merging (286, 1281) with freq 4 into a new token 4236
# merging (643, 351) with freq 4 into a new token 4237
# merging (166, 282) with freq 4 into a new token 4238
# merging (542, 1574) with freq 4 into a new token 4239
# merging (1381, 435) with freq 4 into a new token 4240
# merging (299, 266) with freq 4 into a new token 4241
# merging (959, 409) with freq 4 into a new token 4242
# merging (320, 2406) with freq 4 into a new token 4243
# merging (335, 479) with freq 4 into a new token 4244
# merging (1014, 523) with freq 4 into a new token 4245
# merging (2637, 396) with freq 4 into a new token 4246
# merging (690, 434) with freq 4 into a new token 4247
# merging (273, 335) with freq 4 into a new token 4248
# merging (505, 293) with freq 4 into a new token 4249
# merging (410, 611) with freq 4 into a new token 4250
# merging (174, 292) with freq 4 into a new token 4251
# merging (646, 326) with freq 4 into a new token 4252
# merging (1468, 345) with freq 4 into a new token 4253
# merging (1167, 1686) with freq 4 into a new token 4254
# merging (516, 689) with freq 4 into a new token 4255
# merging (726, 1096) with freq 4 into a new token 4256
# merging (550, 739) with freq 4 into a new token 4257
# merging (579, 651) with freq 4 into a new token 4258
# merging (1405, 386) with freq 4 into a new token 4259
# merging (259, 539) with freq 4 into a new token 4260
# merging (324, 314) with freq 4 into a new token 4261
# merging (167, 3122) with freq 4 into a new token 4262
# merging (4262, 2799) with freq 4 into a new token 4263
# merging (1125, 2030) with freq 4 into a new token 4264
# merging (2403, 262) with freq 4 into a new token 4265
# merging (3013, 2558) with freq 4 into a new token 4266
# merging (271, 374) with freq 4 into a new token 4267
# merging (1926, 413) with freq 4 into a new token 4268
# merging (556, 552) with freq 4 into a new token 4269
# merging (308, 170) with freq 4 into a new token 4270
# merging (1155, 300) with freq 4 into a new token 4271
# merging (391, 318) with freq 4 into a new token 4272
# merging (170, 642) with freq 4 into a new token 4273
# merging (808, 560) with freq 4 into a new token 4274
# merging (299, 472) with freq 4 into a new token 4275
# merging (150, 1127) with freq 4 into a new token 4276
# merging (625, 611) with freq 4 into a new token 4277
# merging (1576, 282) with freq 4 into a new token 4278
# merging (288, 607) with freq 4 into a new token 4279
# merging (267, 458) with freq 4 into a new token 4280
# merging (1058, 408) with freq 4 into a new token 4281
# merging (338, 376) with freq 4 into a new token 4282
# merging (552, 367) with freq 4 into a new token 4283
# merging (889, 307) with freq 4 into a new token 4284
# merging (589, 350) with freq 4 into a new token 4285
# merging (2689, 803) with freq 4 into a new token 4286
# merging (270, 905) with freq 4 into a new token 4287
# merging (2451, 483) with freq 4 into a new token 4288
# merging (292, 589) with freq 4 into a new token 4289
# merging (4289, 1185) with freq 4 into a new token 4290
# merging (432, 392) with freq 4 into a new token 4291
# merging (385, 388) with freq 4 into a new token 4292
# merging (941, 283) with freq 4 into a new token 4293
# merging (317, 154) with freq 4 into a new token 4294
# merging (338, 399) with freq 4 into a new token 4295
# merging (1589, 751) with freq 4 into a new token 4296
# merging (441, 267) with freq 4 into a new token 4297
# merging (268, 1585) with freq 4 into a new token 4298
# merging (2211, 743) with freq 4 into a new token 4299
# merging (343, 299) with freq 4 into a new token 4300
# merging (441, 1009) with freq 4 into a new token 4301
# merging (290, 950) with freq 4 into a new token 4302
# merging (284, 735) with freq 4 into a new token 4303
# merging (257, 3498) with freq 4 into a new token 4304
# merging (549, 393) with freq 4 into a new token 4305
# merging (408, 968) with freq 4 into a new token 4306
# merging (306, 724) with freq 4 into a new token 4307
# merging (644, 444) with freq 4 into a new token 4308
# merging (290, 1221) with freq 4 into a new token 4309
# merging (416, 262) with freq 4 into a new token 4310
# merging (2914, 351) with freq 4 into a new token 4311
# merging (1576, 1497) with freq 4 into a new token 4312
# merging (448, 2305) with freq 4 into a new token 4313
# merging (281, 1096) with freq 4 into a new token 4314
# merging (922, 800) with freq 4 into a new token 4315
# merging (961, 262) with freq 4 into a new token 4316
# merging (344, 408) with freq 4 into a new token 4317
# merging (1054, 376) with freq 4 into a new token 4318
# merging (296, 323) with freq 4 into a new token 4319
# merging (360, 686) with freq 4 into a new token 4320
# merging (1353, 352) with freq 4 into a new token 4321
# merging (861, 844) with freq 4 into a new token 4322
# merging (1083, 673) with freq 4 into a new token 4323
# merging (1156, 2202) with freq 4 into a new token 4324
# merging (465, 365) with freq 4 into a new token 4325
# merging (173, 2714) with freq 4 into a new token 4326
# merging (1277, 318) with freq 4 into a new token 4327
# merging (863, 271) with freq 4 into a new token 4328
# merging (380, 1163) with freq 4 into a new token 4329
# merging (166, 522) with freq 4 into a new token 4330
# merging (310, 799) with freq 4 into a new token 4331
# merging (294, 352) with freq 4 into a new token 4332
# merging (344, 318) with freq 4 into a new token 4333
# merging (1787, 432) with freq 4 into a new token 4334
# merging (292, 362) with freq 4 into a new token 4335
# merging (1362, 307) with freq 4 into a new token 4336
# merging (1224, 886) with freq 4 into a new token 4337
# merging (601, 347) with freq 4 into a new token 4338
# merging (1900, 352) with freq 4 into a new token 4339
# merging (573, 1267) with freq 4 into a new token 4340
# merging (288, 2201) with freq 4 into a new token 4341
# merging (411, 781) with freq 4 into a new token 4342
# merging (279, 367) with freq 4 into a new token 4343
# merging (280, 3521) with freq 4 into a new token 4344
# merging (781, 307) with freq 4 into a new token 4345
# merging (390, 256) with freq 4 into a new token 4346
# merging (4346, 1155) with freq 4 into a new token 4347
# merging (1394, 262) with freq 4 into a new token 4348
# merging (1180, 282) with freq 4 into a new token 4349
# merging (308, 3032) with freq 4 into a new token 4350
# merging (288, 396) with freq 4 into a new token 4351
# merging (320, 407) with freq 4 into a new token 4352
# merging (1292, 585) with freq 4 into a new token 4353
# merging (437, 779) with freq 4 into a new token 4354
# merging (1483, 1893) with freq 4 into a new token 4355
# merging (3533, 2426) with freq 4 into a new token 4356
# merging (260, 526) with freq 3 into a new token 4357
# merging (687, 1255) with freq 3 into a new token 4358
# merging (1913, 3035) with freq 3 into a new token 4359
# merging (605, 306) with freq 3 into a new token 4360
# merging (293, 359) with freq 3 into a new token 4361
# merging (306, 2055) with freq 3 into a new token 4362
# merging (436, 365) with freq 3 into a new token 4363
# merging (4363, 483) with freq 3 into a new token 4364
# merging (276, 498) with freq 3 into a new token 4365
# merging (2057, 259) with freq 3 into a new token 4366
# merging (577, 529) with freq 3 into a new token 4367
# merging (353, 366) with freq 3 into a new token 4368
# merging (888, 731) with freq 3 into a new token 4369
# merging (569, 394) with freq 3 into a new token 4370
# merging (312, 611) with freq 3 into a new token 4371
# merging (549, 1057) with freq 3 into a new token 4372
# merging (764, 3037) with freq 3 into a new token 4373
# merging (591, 465) with freq 3 into a new token 4374
# merging (985, 329) with freq 3 into a new token 4375
# merging (452, 271) with freq 3 into a new token 4376
# merging (536, 267) with freq 3 into a new token 4377
# merging (610, 345) with freq 3 into a new token 4378
# merging (166, 283) with freq 3 into a new token 4379
# merging (1593, 272) with freq 3 into a new token 4380
# merging (798, 406) with freq 3 into a new token 4381
# merging (1059, 307) with freq 3 into a new token 4382
# merging (410, 458) with freq 3 into a new token 4383
# merging (4383, 3040) with freq 3 into a new token 4384
# merging (589, 1135) with freq 3 into a new token 4385
# merging (296, 291) with freq 3 into a new token 4386
# merging (388, 295) with freq 3 into a new token 4387
# merging (989, 990) with freq 3 into a new token 4388
# merging (1340, 382) with freq 3 into a new token 4389
# merging (991, 315) with freq 3 into a new token 4390
# merging (134, 1295) with freq 3 into a new token 4391
# merging (965, 1597) with freq 3 into a new token 4392
# merging (661, 460) with freq 3 into a new token 4393
# merging (762, 281) with freq 3 into a new token 4394
# merging (1344, 344) with freq 3 into a new token 4395
# merging (1297, 412) with freq 3 into a new token 4396
# merging (1138, 547) with freq 3 into a new token 4397
# merging (915, 533) with freq 3 into a new token 4398
# merging (2068, 1400) with freq 3 into a new token 4399
# merging (2457, 439) with freq 3 into a new token 4400
# merging (3567, 1401) with freq 3 into a new token 4401
# merging (708, 383) with freq 3 into a new token 4402
# merging (316, 167) with freq 3 into a new token 4403
# merging (306, 856) with freq 3 into a new token 4404
# merging (1302, 349) with freq 3 into a new token 4405
# merging (421, 287) with freq 3 into a new token 4406
# merging (373, 267) with freq 3 into a new token 4407
# merging (307, 464) with freq 3 into a new token 4408
# merging (336, 293) with freq 3 into a new token 4409
# merging (966, 286) with freq 3 into a new token 4410
# merging (286, 432) with freq 3 into a new token 4411
# merging (281, 2466) with freq 3 into a new token 4412
# merging (322, 457) with freq 3 into a new token 4413
# merging (569, 359) with freq 3 into a new token 4414
# merging (348, 3062) with freq 3 into a new token 4415
# merging (1112, 288) with freq 3 into a new token 4416
# merging (947, 274) with freq 3 into a new token 4417
# merging (809, 2466) with freq 3 into a new token 4418
# merging (932, 1347) with freq 3 into a new token 4419
# merging (501, 440) with freq 3 into a new token 4420
# merging (4420, 776) with freq 3 into a new token 4421
# merging (1011, 344) with freq 3 into a new token 4422
# merging (1405, 382) with freq 3 into a new token 4423
# merging (681, 2072) with freq 3 into a new token 4424
# merging (280, 415) with freq 3 into a new token 4425
# merging (591, 283) with freq 3 into a new token 4426
# merging (1608, 283) with freq 3 into a new token 4427
# merging (809, 1350) with freq 3 into a new token 4428
# merging (395, 1060) with freq 3 into a new token 4429
# merging (280, 2743) with freq 3 into a new token 4430
# merging (280, 442) with freq 3 into a new token 4431
# merging (266, 1109) with freq 3 into a new token 4432
# merging (893, 562) with freq 3 into a new token 4433
# merging (471, 1931) with freq 3 into a new token 4434
# merging (325, 374) with freq 3 into a new token 4435
# merging (318, 358) with freq 3 into a new token 4436
# merging (281, 482) with freq 3 into a new token 4437
# merging (320, 827) with freq 3 into a new token 4438
# merging (1194, 349) with freq 3 into a new token 4439
# merging (3545, 479) with freq 3 into a new token 4440
# merging (1169, 365) with freq 3 into a new token 4441
# merging (1058, 294) with freq 3 into a new token 4442
# merging (377, 1200) with freq 3 into a new token 4443
# merging (1056, 969) with freq 3 into a new token 4444
# merging (1521, 307) with freq 3 into a new token 4445
# merging (538, 474) with freq 3 into a new token 4446
# merging (296, 538) with freq 3 into a new token 4447
# merging (443, 283) with freq 3 into a new token 4448
# merging (1041, 262) with freq 3 into a new token 4449
# merging (166, 290) with freq 3 into a new token 4450
# merging (3600, 330) with freq 3 into a new token 4451
# merging (284, 331) with freq 3 into a new token 4452
# merging (541, 294) with freq 3 into a new token 4453
# merging (4453, 477) with freq 3 into a new token 4454
# merging (2485, 477) with freq 3 into a new token 4455
# merging (355, 287) with freq 3 into a new token 4456
# merging (1351, 340) with freq 3 into a new token 4457
# merging (149, 292) with freq 3 into a new token 4458
# merging (2084, 692) with freq 3 into a new token 4459
# merging (307, 1087) with freq 3 into a new token 4460
# merging (785, 282) with freq 3 into a new token 4461
# merging (577, 475) with freq 3 into a new token 4462
# merging (2721, 513) with freq 3 into a new token 4463
# merging (285, 288) with freq 3 into a new token 4464
# merging (305, 1170) with freq 3 into a new token 4465
# merging (279, 1013) with freq 3 into a new token 4466
# merging (369, 172) with freq 3 into a new token 4467
# merging (280, 554) with freq 3 into a new token 4468
# merging (388, 528) with freq 3 into a new token 4469
# merging (778, 2236) with freq 3 into a new token 4470
# merging (4470, 787) with freq 3 into a new token 4471
# merging (178, 788) with freq 3 into a new token 4472
# merging (541, 2487) with freq 3 into a new token 4473
# merging (572, 322) with freq 3 into a new token 4474
# merging (1706, 2087) with freq 3 into a new token 4475
# merging (342, 282) with freq 3 into a new token 4476
# merging (260, 563) with freq 3 into a new token 4477
# merging (1043, 355) with freq 3 into a new token 4478
# merging (2245, 263) with freq 3 into a new token 4479
# merging (618, 1171) with freq 3 into a new token 4480
# merging (40, 401) with freq 3 into a new token 4481
# merging (276, 418) with freq 3 into a new token 4482
# merging (1146, 2247) with freq 3 into a new token 4483
# merging (784, 995) with freq 3 into a new token 4484
# merging (319, 688) with freq 3 into a new token 4485
# merging (655, 548) with freq 3 into a new token 4486
# merging (162, 3622) with freq 3 into a new token 4487
# merging (326, 1272) with freq 3 into a new token 4488
# merging (974, 406) with freq 3 into a new token 4489
# merging (337, 1085) with freq 3 into a new token 4490
# merging (558, 3113) with freq 3 into a new token 4491
# merging (449, 318) with freq 3 into a new token 4492
# merging (348, 2258) with freq 3 into a new token 4493
# merging (266, 326) with freq 3 into a new token 4494
# merging (784, 365) with freq 3 into a new token 4495
# merging (1089, 511) with freq 3 into a new token 4496
# merging (3629, 1949) with freq 3 into a new token 4497
# merging (736, 351) with freq 3 into a new token 4498
# merging (1946, 314) with freq 3 into a new token 4499

# %%
print("tokens length:", len(tokens))
print("ids length:", len(ids))
print(f"compression ratio: {len(tokens) / len(ids):.2f}X")
# Out:
# tokens length: 516076
# ids length: 55830
# compression ratio: 9.24X
